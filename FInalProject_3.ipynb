# %% [markdown]
# # Importer données

# %%
import pandas
import numpy as np
import statistics
import scipy.stats as stats
# pip install seaborn
import seaborn as sns
# pip install matplotlib
# %matplotlib inline
import matplotlib as plt
import matplotlib.pyplot as plt
import pandas as pd

# %%
df1 = pd.read_csv("/content/CO2.csv", sep=",")
df2 = pd.read_csv("/content/CO2metadata.csv", sep=",")
df_pib = pd.read_csv("/content/pib.csv")
df_srf = pd.read_csv("/content/srf.csv")
df_pop = pd.read_csv("/content/pop.csv")

# %% [markdown]
# ## Le dataset CO2.csv contenait des agrégations tels que "word", "pays ocde", etc,  qui ont été supprimés du fichier pour ne pas considérer des doublons

# %%
df1["Country Name"].unique()
# Out:
# array(['China', 'United States', 'India', 'Russian Federation', 'Japan',
#        'Germany', 'Iran, Islamic Rep.', 'Korea, Rep.', 'Saudi Arabia',
#        'Indonesia', 'Canada', 'Mexico', 'South Africa', 'Brazil',
#        'United Kingdom', 'Australia', 'Turkey', 'Poland', 'Thailand',
#        'Malaysia', 'Kazakhstan', 'Spain', 'Egypt, Arab Rep.',
#        'United Arab Emirates', 'Ukraine', 'Argentina', 'Pakistan',
#        'Vietnam', 'Iraq', 'Netherlands', 'Venezuela, RB', 'Algeria',
#        'Philippines', 'Nigeria', 'Qatar', 'Czech Republic', 'Kuwait',
#        'Colombia', 'Belgium', 'Uzbekistan', 'Chile', 'Bangladesh',
#        'Turkmenistan', 'Romania', 'Israel', 'Oman', 'Greece', 'Austria',
#        'Morocco', 'Belarus', 'Peru', 'Libya', 'Portugal', 'Finland',
#        'Hungary', 'Serbia', 'Trinidad and Tobago', 'Hong Kong SAR, China',
#        'Sweden', 'Bulgaria', 'Ecuador', 'Norway', 'Ireland', 'Azerbaijan',
#        'Singapore', 'Angola', 'Switzerland', 'New Zealand',
#        'Slovak Republic', 'Denmark', 'Bahrain', 'Tunisia',
#        'Syrian Arab Republic', 'Cuba', "Korea, Dem. People's Rep.",
#        'Mongolia', 'Myanmar', 'Dominican Republic', 'Jordan', 'Lebanon',
#        'Sri Lanka', 'Bosnia and Herzegovina', 'Bolivia', 'Sudan', 'Kenya',
#        'Lao PDR', 'Croatia', 'Guatemala', 'Ghana', 'Estonia', 'Ethiopia',
#        'Lithuania', 'Slovenia', 'Tanzania', 'Zimbabwe', 'Senegal',
#        'Panama', 'Yemen, Rep.', 'Georgia', 'Cambodia', 'Honduras',
#        'Kyrgyz Republic', "Cote d'Ivoire", 'Nepal', 'Luxembourg',
#        'Kosovo', 'Afghanistan', 'Cameroon', 'Jamaica', 'Costa Rica',
#        'Mozambique', 'Brunei Darussalam', 'Papua New Guinea', 'Paraguay',
#        'El Salvador', 'North Macedonia', 'Latvia', 'Uruguay', 'Cyprus',
#        'Benin', 'Botswana', 'Uganda', 'Equatorial Guinea', 'Nicaragua',
#        'Curacao', 'New Caledonia', 'Gabon', 'Tajikistan', 'Armenia',
#        'Zambia', 'Moldova', 'Albania', 'Mauritius', 'Namibia',
#        'Madagascar', 'Burkina Faso', 'Pacific island small states',
#        'Congo, Rep.', 'West Bank and Gaza', 'Mali', 'Togo', 'Guinea',
#        'Haiti', 'Mauritania', 'Lesotho', 'Guyana', 'Macao SAR, China',
#        'Iceland', 'Fiji', 'Congo, Dem. Rep.', 'Montenegro', 'Niger',
#        'Bahamas, The', 'Suriname', 'South Sudan', 'Maldives', 'Liberia',
#        'Malta', 'Malawi', 'Barbados', 'Bhutan', 'Eswatini', 'Rwanda',
#        'Sierra Leone', 'Chad', 'Aruba', 'French Polynesia', 'Eritrea',
#        'Somalia', 'Gibraltar', 'Faroe Islands', 'Djibouti', 'Bermuda',
#        'Seychelles', 'Belize', 'Antigua and Barbuda', 'Cayman Islands',
#        'Cabo Verde', 'Gambia, The', 'Greenland', 'Burundi', 'Timor-Leste',
#        'Andorra', 'St. Lucia', 'Central African Republic',
#        'Guinea-Bissau', 'Grenada', 'Samoa', 'St. Kitts and Nevis',
#        'Palau', 'St. Vincent and the Grenadines',
#        'Turks and Caicos Islands', 'British Virgin Islands', 'Comoros',
#        'Dominica', 'Solomon Islands', 'Vanuatu', 'Micronesia, Fed. Sts.',
#        'Marshall Islands', 'Tonga', 'Sao Tome and Principe', 'Kiribati',
#        'Liechtenstein', 'Nauru', 'Tuvalu', 'American Samoa',
#        'Channel Islands', 'France', 'Guam', 'Isle of Man', 'Italy',
#        'St. Martin (French part)', 'Monaco', 'Northern Mariana Islands',
#        'Puerto Rico', 'San Marino', 'Sint Maarten (Dutch part)',
#        'Virgin Islands (U.S.)'], dtype=object)

# %%
df_pop.head(2)
# Out:
#   Country Name Country Code  ...        2018        2019
# 0        Aruba          ABW  ...    105845.0    106314.0
# 1  Afghanistan          AFG  ...  37172386.0  38041754.0
#
# [2 rows x 64 columns]

# %%
df_pop.drop(["Country Name", "Indicator Name", "Indicator Code"], axis=1, inplace=True)

# %% [markdown]
# ## On conserve la surface de 2018

# %%
df_srf = df_srf[["Country Code", "2018"]]

# %%
df_pib.drop(["Country Name", "Indicator Name", "Indicator Code"], axis=1, inplace=True)

# %%
df1.head(2)
# Out:
#     Country Name Country Code  ...          2015         2016
# 0          China          CHN  ...  1.014500e+07  9893037.952
# 1  United States          USA  ...  5.126913e+06  5006302.077
#
# [2 rows x 61 columns]

# %%
df2.head(2)
# Out:
#   Country Code                     Region  ...    TableName Unnamed: 5
# 0          ABW  Latin America & Caribbean  ...        Aruba        NaN
# 1          AFG                 South Asia  ...  Afghanistan        NaN
#
# [2 rows x 6 columns]

# %%
print(df1.shape)
print(df2.shape)
# Out:
# (218, 61)
# (263, 6)

# %% [markdown]
# ## Merge pour avoir Region et Income groupe dans le même dataFrame

# %%
df_co2 = df1.merge(df2, how="left", on="Country Code")
print(df_co2.shape)
# Out:
# (218, 66)

# %%
df_co2.head(2)
# Out:
#     Country Name Country Code  ...      TableName Unnamed: 5
# 0          China          CHN  ...          China        NaN
# 1  United States          USA  ...  United States        NaN
#
# [2 rows x 66 columns]

# %%
print(df_co2["Indicator Name"].unique())
# Out:
# ['CO2 emissions (kt)']

# %%
df_co2 = df_co2.drop('Indicator Name', 1)
df_co2 = df_co2.drop('Indicator Code', 1)
df_co2 = df_co2.drop('Unnamed: 5', 1)
df_co2 = df_co2.drop('TableName', 1)
df_co2 = df_co2.drop('SpecialNotes', 1)

# %%
df_co2 = df_co2.sort_values(by="Country Name")

# %%
df_co2.head()
# Out:
#        Country Name  ...          IncomeGroup
# 106     Afghanistan  ...           Low income
# 131         Albania  ...  Upper middle income
# 31          Algeria  ...  Lower middle income
# 205  American Samoa  ...  Upper middle income
# 182         Andorra  ...          High income
#
# [5 rows x 61 columns]

# %% [markdown]
# ## Transposition des donnees

# %%
df_co2_melt = df_co2.melt(id_vars=["Country Name", "Country Code", "Region","IncomeGroup"])

# %%
df_co2_melt.head()
# Out:
#      Country Name Country Code  ... variable     value
# 0     Afghanistan          AFG  ...     1960   414.371
# 1         Albania          ALB  ...     1960  2024.184
# 2         Algeria          DZA  ...     1960  6160.560
# 3  American Samoa          ASM  ...     1960       NaN
# 4         Andorra          AND  ...     1960       NaN
#
# [5 rows x 6 columns]

# %%
df_co2_melt.columns = ["Country", "Country Code", "Region", "IncomeGroup", "Year", "CO2"]

# %%
df_co2_melt = df_co2_melt.sort_values(by=["Country", "Year"])

# %%
df_co2_melt.head()
# Out:
#          Country Country Code      Region IncomeGroup  Year      CO2
# 0    Afghanistan          AFG  South Asia  Low income  1960  414.371
# 218  Afghanistan          AFG  South Asia  Low income  1961  491.378
# 436  Afghanistan          AFG  South Asia  Low income  1962  689.396
# 654  Afghanistan          AFG  South Asia  Low income  1963  707.731
# 872  Afghanistan          AFG  South Asia  Low income  1964  839.743

# %%
df_co2_melt['CO2_Region_Year'] = df_co2_melt.groupby(['Region', 'Year'])["CO2"].transform('sum')

# %%
df_co2_melt['CO2_IncomeGroup_Year'] = df_co2_melt.groupby(['IncomeGroup', 'Year'])["CO2"].transform('sum')

# %%
df_co2_melt.head(20)
# Out:
#           Country Country Code  ... CO2_Region_Year CO2_IncomeGroup_Year
# 0     Afghanistan          AFG  ...      151645.118            36460.981
# 218   Afghanistan          AFG  ...      162624.116            39706.276
# 436   Afghanistan          AFG  ...      179019.273            43934.327
# 654   Afghanistan          AFG  ...      194453.676            46823.923
# 872   Afghanistan          AFG  ...      191982.118            51437.009
# 1090  Afghanistan          AFG  ...      209767.068            61011.546
# 1308  Afghanistan          AFG  ...      216364.001            66545.049
# 1526  Afghanistan          AFG  ...      219829.316            72001.545
# 1744  Afghanistan          AFG  ...      241530.622            83519.592
# 1962  Afghanistan          AFG  ...      244372.547            92525.744
# 2180  Afghanistan          AFG  ...      249319.330           102257.962
# 2398  Afghanistan          AFG  ...      257320.724           140196.744
# 2616  Afghanistan          AFG  ...      245637.662           120743.309
# 2834  Afghanistan          AFG  ...      254691.485           129371.760
# 3052  Afghanistan          AFG  ...      263356.606           136207.048
# 3270  Afghanistan          AFG  ...      285677.635           142433.614
# 3488  Afghanistan          AFG  ...      297283.690           146177.621
# 3706  Afghanistan          AFG  ...      314921.960           151934.811
# 3924  Afghanistan          AFG  ...      321225.533           147325.392
# 4142  Afghanistan          AFG  ...      338423.763           159151.467
#
# [20 rows x 8 columns]

# %%
df_co2_region_year = df_co2_melt[["Region", "Year", "CO2_Region_Year"]]
print(df_co2_region_year.shape)
# Out:
# (12426, 3)

# %%
df_co2_region_year = df_co2_region_year.drop_duplicates()
print(df_co2_region_year.shape)
# Out:
# (456, 3)

# %%
df_co2_region_year = df_co2_region_year[df_co2_region_year["Region"].notnull()]
print(df_co2_region_year.shape)
# Out:
# (399, 3)

# %%
df_co2_region_year.head(20)
# Out:
#           Region  Year  CO2_Region_Year
# 0     South Asia  1960       151645.118
# 218   South Asia  1961       162624.116
# 436   South Asia  1962       179019.273
# 654   South Asia  1963       194453.676
# 872   South Asia  1964       191982.118
# 1090  South Asia  1965       209767.068
# 1308  South Asia  1966       216364.001
# 1526  South Asia  1967       219829.316
# 1744  South Asia  1968       241530.622
# 1962  South Asia  1969       244372.547
# 2180  South Asia  1970       249319.330
# 2398  South Asia  1971       257320.724
# 2616  South Asia  1972       245637.662
# 2834  South Asia  1973       254691.485
# 3052  South Asia  1974       263356.606
# 3270  South Asia  1975       285677.635
# 3488  South Asia  1976       297283.690
# 3706  South Asia  1977       314921.960
# 3924  South Asia  1978       321225.533
# 4142  South Asia  1979       338423.763

# %%
df_co2_Incomegroup_year = df_co2_melt[["IncomeGroup", "Year", "CO2_IncomeGroup_Year"]]
print(df_co2_Incomegroup_year.shape)
# Out:
# (12426, 3)

# %%
df_co2_Incomegroup_year = df_co2_Incomegroup_year.drop_duplicates()
print(df_co2_Incomegroup_year.shape)
# Out:
# (285, 3)

# %%
df_co2_Incomegroup_year = df_co2_Incomegroup_year[df_co2_Incomegroup_year["IncomeGroup"].notnull()]
print(df_co2_Incomegroup_year.shape)
# Out:
# (228, 3)

# %%
df_co2_Incomegroup_year_pivot = df_co2_Incomegroup_year.pivot("IncomeGroup", "Year", "CO2_IncomeGroup_Year")

# %%
df_co2_Incomegroup_year_pivot.head()
# Out:
# Year                        1960         1961  ...          2015          2016
# IncomeGroup                                    ...
# High income          5163044.325  5277047.688  ...  1.200871e+07  1.177276e+07
# Low income             36460.981    39706.276  ...  1.607649e+05  1.643183e+05
# Lower middle income   211160.528   224457.070  ...  4.101459e+06  4.229048e+06
# Upper middle income  2708981.582  2543500.873  ...  1.683839e+07  1.671832e+07
#
# [4 rows x 57 columns]

# %%
df_co2_region_year_pivot = df_co2_region_year.pivot("Region", "Year", "CO2_Region_Year")

# %%
df_co2_region_year_pivot
# Out:
# Year                               1960  ...          2016
# Region                                   ...
# East Asia & Pacific         1202974.018  ...  1.368487e+07
# Europe & Central Asia       3166989.882  ...  5.639908e+06
# Latin America & Caribbean    297987.754  ...  1.815792e+06
# Middle East & North Africa    98634.966  ...  2.608737e+06
# North America               3083748.982  ...  5.551809e+06
# South Asia                   151645.118  ...  2.736913e+06
# Sub-Saharan Africa           117666.696  ...  8.464133e+05
#
# [7 rows x 57 columns]

# %% [markdown]
# # Analyse Monovarie

# %% [markdown]
# ### Evolution d'emition de CO2 par region

# %%
plt.figure(figsize=(10,5))
h1 =sns.heatmap(df_co2_region_year_pivot, cmap="Blues")
h1.set(title='East Asia & Pacifique est la région la plus polluante')
h1.title.set_size(17)

# %% [markdown]
# ### Evolution des émissions de CO2 par niveau de Income

# %%
plt.figure(figsize=(10,5))
g = sns.heatmap(df_co2_Incomegroup_year_pivot, cmap="Blues")
g.set(title='Les pays riches polluent plus')
g.title.set_size(20)

# %%
df_co2_Incomegroup_year.head(2)
# g.set_xticklabels(g.get_xticklabels(), rotation=30)
# Out:
#     IncomeGroup  Year  CO2_IncomeGroup_Year
# 0    Low income  1960             36460.981
# 218  Low income  1961             39706.276

# %%
plt.figure(figsize=(25,10))
g = sns.lineplot(data=df_co2_Incomegroup_year, x="Year", y="CO2_IncomeGroup_Year", hue="IncomeGroup")
labels = df_co2_Incomegroup_year["Year"].unique()
labelsy=df_co2_Incomegroup_year["CO2_IncomeGroup_Year"].unique()
# g.set_xticks(len(labels))
g.set(title='Les pays riches évoluent plus')
g.title.set_size(40)
g.xaxis.label.set_size(16)
g.yaxis.label.set_size(16)
#g.legend(fontsize=500) # using a size in points
g.legend(fontsize="larger")
g.legend(loc='center left',bbox_to_anchor=(1, 0.5))
g.grid()
g.tick_params(axis='x',which='minor',direction='out',bottom=True,length=5)
g.set_xticklabels(labels,  rotation=90, 
    horizontalalignment='center',
    fontweight='light',
    fontsize='x-large')
g.set_yticklabels(labelsy.astype(int),
    fontweight='light',
    fontsize='x-large')
# Out:
# [Text(0, 0, '36460'),
#  Text(0, 0, '39706'),
#  Text(0, 0, '43934'),
#  Text(0, 0, '46823'),
#  Text(0, 0, '51437'),
#  Text(0, 0, '61011'),
#  Text(0, 0, '66545'),
#  Text(0, 0, '72001'),
#  Text(0, 0, '83519'),
#  Text(0, 0, '92525')]

# %%
plt.figure(figsize=(25,10))
g = sns.lineplot(data=df_co2_region_year, x="Year", y="CO2_Region_Year", hue="Region")
labels = df_co2_region_year["Year"].unique()
labelsy=df_co2_region_year["CO2_Region_Year"].unique()
g.set(title='East Asia & Pacific se démarquent du reste du monde')
g.title.set_size(40)
g.xaxis.label.set_size(16)
g.yaxis.label.set_size(16)
g.legend(fontsize=50)
g.legend(fontsize="larger")
g.legend(loc='center left',bbox_to_anchor=(1, 0.5))
g.grid()
g.tick_params(axis='x',which='minor',direction='out',bottom=True,length=5)
g.set_xticklabels(labels,  rotation=90, 
    horizontalalignment='center',
    fontweight='light',
    fontsize='x-large')
g.set_yticklabels(labelsy.astype(int),
    fontweight='light',
    fontsize='x-large')
# Out:
# [Text(0, 0, '151645'),
#  Text(0, 0, '162624'),
#  Text(0, 0, '179019'),
#  Text(0, 0, '194453'),
#  Text(0, 0, '191982'),
#  Text(0, 0, '209767'),
#  Text(0, 0, '216364'),
#  Text(0, 0, '219829'),
#  Text(0, 0, '241530'),
#  Text(0, 0, '244372')]

# %%
df1['Country Name'] = df1['Country Name'].astype("category")

# %%
df1.dtypes
# Out:
# Country Name      category
# Country Code        object
# Indicator Name      object
# Indicator Code      object
# 1960               float64
#                     ...
# 2012               float64
# 2013               float64
# 2014               float64
# 2015               float64
# 2016               float64
# Length: 61, dtype: object

# %% [raw]
# df1['Country Name'] = df1['Country Name'].cat.as_ordered()
# df1 = df1.set_index('Country Name')

# %%
df_co2.shape
# Out:
# (218, 61)

# %%
df_co2_melt.head(2)
# Out:
#          Country Country Code  ... CO2_Region_Year CO2_IncomeGroup_Year
# 0    Afghanistan          AFG  ...      151645.118            36460.981
# 218  Afghanistan          AFG  ...      162624.116            39706.276
#
# [2 rows x 8 columns]

# %%
df_pib.head()
# Out:
#   Country Code         1960  ...          2018          2019
# 0          ABW          NaN  ...           NaN           NaN
# 1          AFG  537777811.1  ...  1.835388e+10  1.929110e+10
# 2          AGO          NaN  ...  1.013530e+11  8.881570e+10
# 3          ALB          NaN  ...  1.514702e+10  1.527918e+10
# 4          AND          NaN  ...  3.218316e+09  3.154058e+09
#
# [5 rows x 61 columns]

# %%
df_pib_melt = df_pib.melt(id_vars=["Country Code"])

# %%
df_pib_melt.head()
# Out:
#   Country Code variable        value
# 0          ABW     1960          NaN
# 1          AFG     1960  537777811.1
# 2          AGO     1960          NaN
# 3          ALB     1960          NaN
# 4          AND     1960          NaN

# %%
df_pib_melt.columns = ["Country Code", "Year", "PIB"]

# %%
df_pop_melt = df_pop.melt(id_vars=["Country Code"])

# %%
df_pop_melt.columns = ["Country Code", "Year", "Population"]

# %%
df_pib_melt.head(2)
# Out:
#   Country Code  Year          PIB
# 0          ABW  1960          NaN
# 1          AFG  1960  537777811.1

# %%
df_pop_melt.head(2)
# Out:
#   Country Code  Year  Population
# 0          ABW  1960     54211.0
# 1          AFG  1960   8996973.0

# %%
df_srf.columns = ["Country Code", "Surface"]

# %%
print(df_pib_melt.shape)
df_pib_melt = df_pib_melt.merge(df_srf, how="left", on="Country Code")
print(df_pib_melt.shape)
# Out:
# (15840, 3)
# (15840, 4)

# %%
print(df_pib_melt.shape)
df_pib_melt = df_pib_melt.merge(df_pop_melt, how="left", on=["Country Code", "Year"])
print(df_pib_melt.shape)
# Out:
# (15840, 4)
# (15840, 5)

# %%
print(df_co2_melt.shape)
df_all = df_co2_melt.merge(df_pib_melt, how="left", on=["Country Code", "Year"])
print(df_all.shape)
# Out:
# (12426, 8)
# (12426, 11)

# %%
df_co2_melt.head(2)
# Out:
#          Country Country Code  ... CO2_Region_Year CO2_IncomeGroup_Year
# 0    Afghanistan          AFG  ...      151645.118            36460.981
# 218  Afghanistan          AFG  ...      162624.116            39706.276
#
# [2 rows x 8 columns]

# %%
df_pib_melt.head(2)
# Out:
#   Country Code  Year          PIB   Surface  Population
# 0          ABW  1960          NaN     180.0     54211.0
# 1          AFG  1960  537777811.1  652860.0   8996973.0

# %%
df_all['PIB/Capita'] = df_all['PIB']/df_all['Population']

# %%
df_all['CO2/Capita'] = df_all['CO2']/df_all['Population']

# %%
df_all.head(100)
# Out:
#         Country Country Code  ...   PIB/Capita CO2/Capita
# 0   Afghanistan          AFG  ...    59.773194   0.000046
# 1   Afghanistan          AFG  ...    59.860874   0.000054
# 2   Afghanistan          AFG  ...    58.458015   0.000074
# 3   Afghanistan          AFG  ...    78.706388   0.000074
# 4   Afghanistan          AFG  ...    82.095231   0.000086
# ..          ...          ...  ...          ...        ...
# 95      Albania          ALB  ...   813.790263   0.000560
# 96      Albania          ALB  ...  1033.241693   0.000960
# 97      Albania          ALB  ...  1126.683318   0.000978
# 98      Albania          ALB  ...  1281.659393   0.001053
# 99      Albania          ALB  ...  1425.124849   0.001230
#
# [100 rows x 13 columns]

# %%
df_all.columns
# Out:
# Index(['Country', 'Country Code', 'Region', 'IncomeGroup', 'Year', 'CO2',
#        'CO2_Region_Year', 'CO2_IncomeGroup_Year', 'PIB', 'Surface',
#        'Population', 'PIB/Capita', 'CO2/Capita'],
#       dtype='object')

# %%
print(df_all.shape)
df_corr = df_all[['CO2', 'PIB', 'Surface', 'Population', 'PIB/Capita', 'CO2/Capita']].drop_duplicates()
print(df_corr.shape)
# Out:
# (12426, 13)
# (12396, 6)

# %%
df_corr.head()
# Out:
#        CO2          PIB   Surface  Population  PIB/Capita  CO2/Capita
# 0  414.371  537777811.1  652860.0   8996973.0   59.773194    0.000046
# 1  491.378  548888895.6  652860.0   9169410.0   59.860874    0.000054
# 2  689.396  546666677.8  652860.0   9351441.0   58.458015    0.000074
# 3  707.731  751111191.1  652860.0   9543205.0   78.706388    0.000074
# 4  839.743  800000044.4  652860.0   9744781.0   82.095231    0.000086

# %% [markdown]
# # EXTRACT COUNTRIES WITH THEIR CORRELATION CO2/PIB

# %%
countries = df_all["Country"].unique().tolist()

# %%
df_Alemania = df_all[df_all["Country"]=="Germany"][["Country", 'Year', 'CO2', 'PIB']].drop_duplicates()

# %%
print(df_Alemania)
# Out:
#       Country  Year         CO2           PIB
# 4161  Germany  1960         NaN           NaN
# 4162  Germany  1961         NaN           NaN
# 4163  Germany  1962         NaN           NaN
# 4164  Germany  1963         NaN           NaN
# 4165  Germany  1964         NaN           NaN
# 4166  Germany  1965         NaN           NaN
# 4167  Germany  1966         NaN           NaN
# 4168  Germany  1967         NaN           NaN
# 4169  Germany  1968         NaN           NaN
# 4170  Germany  1969         NaN           NaN
# 4171  Germany  1970         NaN  2.158380e+11
# 4172  Germany  1971         NaN  2.499850e+11
# 4173  Germany  1972         NaN  2.998020e+11
# 4174  Germany  1973         NaN  3.983740e+11
# 4175  Germany  1974         NaN  4.453030e+11
# 4176  Germany  1975         NaN  4.906370e+11
# 4177  Germany  1976         NaN  5.197540e+11
# 4178  Germany  1977         NaN  6.004980e+11
# 4179  Germany  1978         NaN  7.404700e+11
# 4180  Germany  1979         NaN  8.813450e+11
# 4181  Germany  1980         NaN  9.502910e+11
# 4182  Germany  1981         NaN  8.004720e+11
# 4183  Germany  1982         NaN  7.765760e+11
# 4184  Germany  1983         NaN  7.706840e+11
# 4185  Germany  1984         NaN  7.251110e+11
# 4186  Germany  1985         NaN  7.325350e+11
# 4187  Germany  1986         NaN  1.046260e+12
# 4188  Germany  1987         NaN  1.298180e+12
# 4189  Germany  1988         NaN  1.401230e+12
# 4190  Germany  1989         NaN  1.398970e+12
# 4191  Germany  1990         NaN  1.771670e+12
# 4192  Germany  1991  929973.202  1.868950e+12
# 4193  Germany  1992  891975.748  2.131570e+12
# 4194  Germany  1993  877645.112  2.071320e+12
# 4195  Germany  1994  865558.680  2.205070e+12
# 4196  Germany  1995  864110.215  2.585790e+12
# 4197  Germany  1996  889614.200  2.497240e+12
# 4198  Germany  1997  862276.715  2.211990e+12
# 4199  Germany  1998  855364.420  2.238990e+12
# 4200  Germany  1999  822460.429  2.194200e+12
# 4201  Germany  2000  829977.779  1.943150e+12
# 4202  Germany  2001  853662.932  1.944110e+12
# 4203  Germany  2002  829724.756  2.068620e+12
# 4204  Germany  2003  823003.145  2.496130e+12
# 4205  Germany  2004  815969.839  2.809190e+12
# 4206  Germany  2005  797759.517  2.845800e+12
# 4207  Germany  2006  816721.574  2.992200e+12
# 4208  Germany  2007  781247.016  3.421230e+12
# 4209  Germany  2008  779296.172  3.730030e+12
# 4210  Germany  2009  720547.165  3.397790e+12
# 4211  Germany  2010  757880.892  3.396350e+12
# 4212  Germany  2011  729810.007  3.744410e+12
# 4213  Germany  2012  738141.431  3.527340e+12
# 4214  Germany  2013  757961.566  3.732740e+12
# 4215  Germany  2014  720363.815  3.883920e+12
# 4216  Germany  2015  727045.089  3.356240e+12
# 4217  Germany  2016  727972.840  3.467500e+12

# %%
positive_dict_of_countries_according_PIB_CO2_corr = {}
negative_dict_of_countries_according_PIB_CO2_corr = {}
indxP = 0
indxN = 0
for country in countries:
    temp = df_all[df_all["Country"]==country][["Country", 'CO2', 'PIB']].drop_duplicates()
    if temp.corr()["PIB"][0]>0:
        positive_dict_of_countries_according_PIB_CO2_corr[indxP] = (country , temp.corr()["PIB"][0])
        indxP += 1
    else:
        negative_dict_of_countries_according_PIB_CO2_corr[indxN] = (country , temp.corr()["PIB"][0])
        indxN += 1

# %%
print(positive_dict_of_countries_according_PIB_CO2_corr)
# Out:
# {0: ('Afghanistan', 0.9459049257219457), 1: ('Albania', 0.02734881790906836), 2: ('Algeria', 0.8677806234395782), 3: ('Andorra', 0.6005072026004475), 4: ('Angola', 0.9653740803699465), 5: ('Antigua and Barbuda', 0.7521599058322416), 6: ('Argentina', 0.9097698000239125), 7: ('Armenia', 0.8022491261311975), 8: ('Aruba', 0.6243242694770029), 9: ('Australia', 0.8355759939137194), 10: ('Austria', 0.7296779991405956), 11: ('Azerbaijan', 0.0026874978521231087), 12: ('Bahrain', 0.9596994736138096), 13: ('Bangladesh', 0.9427828221398199), 14: ('Barbados', 0.934998791499511), 15: ('Belarus', 0.09358084156429206), 16: ('Belize', 0.9400001048946862), 17: ('Benin', 0.9845999520949712), 18: ('Bermuda', 0.6366096568019373), 19: ('Bhutan', 0.9237900385594157), 20: ('Bolivia', 0.9390685565950042), 21: ('Bosnia and Herzegovina', 0.9404237230589285), 22: ('Botswana', 0.9378824465943261), 23: ('Brazil', 0.9099752177309378), 24: ('Brunei Darussalam', 0.4715824833401096), 25: ('Burkina Faso', 0.9769845301384774), 26: ('Burundi', 0.9121686592004367), 27: ('Cabo Verde', 0.9674354197449577), 28: ('Cambodia', 0.983715779086639), 29: ('Cameroon', 0.7688659011247864), 30: ('Canada', 0.7947147230451654), 31: ('Cayman Islands', 0.16630664851817795), 32: ('Central African Republic', 0.8089361212899359), 33: ('Chad', 0.9108481287720094), 34: ('Chile', 0.9438436559379599), 35: ('China', 0.9384538499945462), 36: ('Colombia', 0.8602557598907483), 37: ('Comoros', 0.8781490165349048), 38: ('Congo, Dem. Rep.', 0.0845869436230984), 39: ('Congo, Rep.', 0.7718563026743979), 40: ('Costa Rica', 0.8760029363763386), 41: ("Cote d'Ivoire", 0.8045435830259074), 42: ('Croatia', 0.16519808082373738), 43: ('Cuba', 0.1820475165581106), 44: ('Curacao', 0.34456999053395854), 45: ('Cyprus', 0.865516968152823), 46: ('Djibouti', 0.9463683552272815), 47: ('Dominica', 0.9589846018418257), 48: ('Dominican Republic', 0.8769348470374084), 49: ('Ecuador', 0.9128681117810025), 50: ('Egypt, Arab Rep.', 0.9257584251499671), 51: ('El Salvador', 0.9404658732934321), 52: ('Equatorial Guinea', 0.8498295030404027), 53: ('Estonia', 0.10990121084812225), 54: ('Eswatini', 0.801698886177776), 55: ('Ethiopia', 0.9599491194310084), 56: ('Fiji', 0.892002305546682), 57: ('Finland', 0.591437884096867), 58: ('French Polynesia', 0.7733788406614135), 59: ('Gabon', 0.38752098128362467), 60: ('Gambia, The', 0.9294130736521871), 61: ('Georgia', 0.4463176320197691), 62: ('Ghana', 0.9341822705337895), 63: ('Greece', 0.8176117903614218), 64: ('Greenland', 0.3625144412069435), 65: ('Grenada', 0.9658696419609275), 66: ('Guatemala', 0.9336495164206506), 67: ('Guinea', 0.8783738575423002), 68: ('Guinea-Bissau', 0.8215235619940384), 69: ('Guyana', 0.5657099656713686), 70: ('Haiti', 0.9466005097178976), 71: ('Honduras', 0.9504721371188491), 72: ('Hong Kong SAR, China', 0.9148412876402229), 73: ('Iceland', 0.7499297825115199), 74: ('India', 0.9700143398631362), 75: ('Indonesia', 0.9044307357357996), 76: ('Iran, Islamic Rep.', 0.8912596153860222), 77: ('Iraq', 0.8740109963788993), 78: ('Ireland', 0.7770528969011542), 79: ('Israel', 0.9043509574523066), 80: ('Italy', 0.6642413594392184), 81: ('Jamaica', 0.6458033269940763), 82: ('Japan', 0.8467734635841402), 83: ('Jordan', 0.8806490872379618), 84: ('Kazakhstan', 0.7828078296101914), 85: ('Kenya', 0.9293089634365231), 86: ('Kiribati', 0.8896512801437321), 87: ('Korea, Rep.', 0.9504716156734275), 88: ('Kuwait', 0.8998938709218038), 89: ('Kyrgyz Republic', 0.7622239770503103), 90: ('Lao PDR', 0.8461603562925343), 91: ('Lebanon', 0.9552382794329335), 92: ('Lesotho', 0.9406385665710844), 93: ('Liberia', 0.9046890966050801), 94: ('Libya', 0.6048746803051519), 95: ('Macao SAR, China', 0.5141091779009509), 96: ('Madagascar', 0.8798986191467425), 97: ('Malawi', 0.8747115607538235), 98: ('Malaysia', 0.9575268481238032), 99: ('Maldives', 0.9804461606229677), 100: ('Mali', 0.9737162690858121), 101: ('Malta', 0.6461520700673358), 102: ('Marshall Islands', 0.9610730494246562), 103: ('M ...

# %%
print(negative_dict_of_countries_according_PIB_CO2_corr)
# Out:
# {0: ('American Samoa', nan), 1: ('Bahamas, The', -0.29603526288793774), 2: ('Belgium', -0.4007155968723603), 3: ('British Virgin Islands', nan), 4: ('Bulgaria', -0.4192363675704775), 5: ('Channel Islands', nan), 6: ('Czech Republic', -0.7810220693917245), 7: ('Denmark', -0.6453054742543956), 8: ('Eritrea', -0.5866735971161017), 9: ('Faroe Islands', -0.5700057273305719), 10: ('France', -0.3667580001224113), 11: ('Germany', -0.8811905911409774), 12: ('Gibraltar', nan), 13: ('Guam', nan), 14: ('Hungary', -0.7729138098632526), 15: ('Isle of Man', nan), 16: ("Korea, Dem. People's Rep.", nan), 17: ('Kosovo', -0.12098442790303736), 18: ('Latvia', -0.2329525110601544), 19: ('Liechtenstein', -0.7070357058665592), 20: ('Lithuania', -0.3257263204202999), 21: ('Luxembourg', -0.2846726811795975), 22: ('Moldova', -0.22093259350170624), 23: ('Monaco', nan), 24: ('North Macedonia', -0.8555379691517153), 25: ('Northern Mariana Islands', nan), 26: ('Poland', -0.6749288695135096), 27: ('Puerto Rico', nan), 28: ('Romania', -0.586926254815409), 29: ('Russian Federation', -0.16202422559854715), 30: ('San Marino', nan), 31: ('Serbia', -0.36233009538711436), 32: ('Slovak Republic', -0.841782533365401), 33: ('South Sudan', -0.32430477880794806), 34: ('St. Martin (French part)', nan), 35: ('Sweden', -0.677386699306302), 36: ('Ukraine', -0.38233400294657743), 37: ('United Kingdom', -0.8408003398059737), 38: ('Uzbekistan', -0.6262482930539474), 39: ('Virgin Islands (U.S.)', nan)}

# %%
for i in negative_dict_of_countries_according_PIB_CO2_corr:
    print(negative_dict_of_countries_according_PIB_CO2_corr.get(i))
# Out:
# ('American Samoa', nan)
# ('Bahamas, The', -0.29603526288793774)
# ('Belgium', -0.4007155968723603)
# ('British Virgin Islands', nan)
# ('Bulgaria', -0.4192363675704775)
# ('Channel Islands', nan)
# ('Czech Republic', -0.7810220693917245)
# ('Denmark', -0.6453054742543956)
# ('Eritrea', -0.5866735971161017)
# ('Faroe Islands', -0.5700057273305719)
# ('France', -0.3667580001224113)
# ('Germany', -0.8811905911409774)
# ('Gibraltar', nan)
# ('Guam', nan)
# ('Hungary', -0.7729138098632526)
# ('Isle of Man', nan)
# ("Korea, Dem. People's Rep.", nan)
# ('Kosovo', -0.12098442790303736)
# ('Latvia', -0.2329525110601544)
# ('Liechtenstein', -0.7070357058665592)
# ('Lithuania', -0.3257263204202999)
# ('Luxembourg', -0.2846726811795975)
# ('Moldova', -0.22093259350170624)
# ('Monaco', nan)
# ('North Macedonia', -0.8555379691517153)
# ('Northern Mariana Islands', nan)
# ('Poland', -0.6749288695135096)
# ('Puerto Rico', nan)
# ('Romania', -0.586926254815409)
# ('Russian Federation', -0.16202422559854715)
# ('San Marino', nan)
# ('Serbia', -0.36233009538711436)
# ('Slovak Republic', -0.841782533365401)
# ('South Sudan', -0.32430477880794806)
# ('St. Martin (French part)', nan)
# ('Sweden', -0.677386699306302)
# ('Ukraine', -0.38233400294657743)
# ('United Kingdom', -0.8408003398059737)
# ('Uzbekistan', -0.6262482930539474)
# ('Virgin Islands (U.S.)', nan)

# %%
g=sns.heatmap(df_Alemania.corr(), annot=True, cmap="Blues")
g.set(title='Le PIB, la superficie et la population sont les plus corrélés au CO2')
g.title.set_size(20)

# %%
df_Alemania.corr()["PIB"][0]
# Out:
# -0.8811905911409774

# %% [markdown]
# # Analyse bivariée

# %% [markdown]
# ### Matrice de correlation

# %%
plt.figure(figsize=(14,10))
g=sns.heatmap(df_corr.corr(), annot=True, cmap="Blues")
g.set(title='Le PIB, la superficie et la population sont les plus corrélés au CO2')
g.title.set_size(20)

# %% [markdown]
# ### Tableau de contingence 2016

# %%
df_cont16 = df_all[df_all['Year']=="2016"]

t_contingence2016 = pd.crosstab(df_cont16['Region'],
                            df_cont16['IncomeGroup'], 
                               margins = False)
print(t_contingence2016)
# Out:
# IncomeGroup                 High income  ...  Upper middle income
# Region                                   ...
# East Asia & Pacific                  14  ...                   10
# Europe & Central Asia                38  ...                   15
# Latin America & Caribbean            17  ...                   20
# Middle East & North Africa            8  ...                    5
# North America                         3  ...                    0
# South Asia                            0  ...                    1
# Sub-Saharan Africa                    2  ...                    5
#
# [7 rows x 4 columns]

# %% [markdown]
# ### Tableau de contingence 1960

# %%
df_cont60 = df_all[df_all['Year']=="1960"]

t_contingence1960 = pd.crosstab(df_cont60['Region'],
                            df_cont60['IncomeGroup'], 
                               margins = False)
print(t_contingence1960)
# Out:
# IncomeGroup                 High income  ...  Upper middle income
# Region                                   ...
# East Asia & Pacific                  14  ...                   10
# Europe & Central Asia                38  ...                   15
# Latin America & Caribbean            17  ...                   20
# Middle East & North Africa            8  ...                    5
# North America                         3  ...                    0
# South Asia                            0  ...                    1
# Sub-Saharan Africa                    2  ...                    5
#
# [7 rows x 4 columns]

# %% [markdown]
# ## Nuage des points

# %%
df_all2016 = df_all[df_all["Year"]=="2016"]

# %% [markdown]
# ## Bivarie entre PIB et CO2

# %%
plt.figure(figsize=(15,10))
ax = df_Alemania.plot(x="Year", y="CO2", legend=False)
ax2 = ax.twinx()
df_Alemania.plot(x="Year", y="PIB", ax=ax2, legend=False, color="r")
plt.show()

# %% [markdown]
# ### Hypothèse : les points orange representent la Chine et les rouges les Etats Unis

# %%
plt.figure(figsize=(15,10))
g=sns.scatterplot(data=df_all, x="PIB", y="CO2", hue="IncomeGroup")
g.set(title='Bivarie entre PIB et CO2')
g.title.set_size(20)

# %% [markdown]
# ### le même pour 2016

# %%
plt.figure(figsize=(15,10))
g=sns.scatterplot(data=df_all2016, x="PIB", y="CO2", hue="IncomeGroup")
g.set(title='Focus sur année 2016')
g.title.set_size(20)

# %% [markdown]
# #### On voit qu'il y a deux pays qui sont des valeurs Extremes (outliers)

# %% [markdown]
# ## Bivarie entre Population et CO2

# %%
plt.figure(figsize=(15,10))
g=sns.scatterplot(data=df_all, x="Population", y="CO2", hue="IncomeGroup")
g.set(title='Lien entre population et émission de CO2')
g.title.set_size(20)

# %% [markdown]
# ## Top 10 des pays les plus polluants en 2016

# %%
df_all2016['pctg_CO2_2016'] = (df_all2016['CO2'] / df_all2016['CO2'].sum())*100
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_all2016 = df_all2016.sort_values(by="pctg_CO2_2016", ascending = False)

# %%
df_all2016.head()
# Out:
#                   Country Country Code  ... CO2/Capita pctg_CO2_2016
# 2393                China          CHN  ...   0.007176     30.081164
# 11855       United States          USA  ...   0.015502     15.222361
# 5129                India          IND  ...   0.001818      7.320862
# 9290   Russian Federation          RUS  ...   0.011999      5.266469
# 5642                Japan          JPN  ...   0.008944      3.453821
#
# [5 rows x 14 columns]

# %% [markdown]
# ### Conserver que les dix les plus polluants en 2016

# %%
df_top10 = df_all2016.head(10)

# %%
df_top10['Country'].unique().tolist()
# Out:
# ['China',
#  'United States',
#  'India',
#  'Russian Federation',
#  'Japan',
#  'Germany',
#  'Iran, Islamic Rep.',
#  'Korea, Rep.',
#  'Saudi Arabia',
#  'Indonesia']

# %%
df_all_top = df_all[df_all['Country'].isin(df_top10['Country'].unique().tolist())]

# %%
df_all_top.head(10)
# Out:
#      Country Country Code  ...  PIB/Capita CO2/Capita
# 2337   China          CHN  ...   89.520542   0.001170
# 2338   China          CHN  ...   75.805838   0.000836
# 2339   China          CHN  ...   70.909412   0.000661
# 2340   China          CHN  ...   74.313643   0.000640
# 2341   China          CHN  ...   85.498555   0.000626
# 2342   China          CHN  ...   98.486778   0.000666
# 2343   China          CHN  ...  104.324566   0.000711
# 2344   China          CHN  ...   96.589532   0.000574
# 2345   China          CHN  ...   91.472718   0.000605
# 2346   China          CHN  ...  100.129903   0.000725
#
# [10 rows x 13 columns]

# %%
df_all_top['CO2/surface'] = df_all_top['CO2']/df_all_top['Surface']
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_all_top['CO2/population'] = df_all_top['CO2']/df_all_top['Population']
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_all_top = df_all_top.drop_duplicates()

# %%
df_all_top.head()
# Out:
#      Country Country Code  ... CO2/surface CO2/population
# 2337   China          CHN  ...    0.081326       0.001170
# 2338   China          CHN  ...    0.057507       0.000836
# 2339   China          CHN  ...    0.045871       0.000661
# 2340   China          CHN  ...    0.045489       0.000640
# 2341   China          CHN  ...    0.045513       0.000626
#
# [5 rows x 15 columns]

# %% [markdown]
# ## Evolution des emissions de CO2/surface du top 10 de 2016

# %%
plt.figure(figsize=(19,10))

g = sns.lineplot(data=df_all_top, x="Year", y="CO2/surface", hue="Country")

g.set(title='Emissions de CO2/surface des 10 les plus polluants en 2016')
g.title.set_size(30)
g.xaxis.label.set_size(16)
g.yaxis.label.set_size(16)
# g.legend(fontsize=100)
g.legend(fontsize="larger")
g.legend(loc='center left',bbox_to_anchor=(1, 0.5))
g.grid()
g.tick_params(axis='x',which='minor',direction='out',bottom=True,length=5)
g.set_xticklabels(labels,  rotation=90, 
    horizontalalignment='center',
    fontweight='light',
    fontsize='x-large')
g.set_yticklabels(labelsy.astype(int),
    fontweight='light',
    fontsize='x-large')
# Out:
# [Text(0, 0, '151645'),
#  Text(0, 0, '162624'),
#  Text(0, 0, '179019'),
#  Text(0, 0, '194453'),
#  Text(0, 0, '191982'),
#  Text(0, 0, '209767'),
#  Text(0, 0, '216364'),
#  Text(0, 0, '219829'),
#  Text(0, 0, '241530')]

# %% [markdown]
# ## Evolution des emissions de CO2/population du top 10 de 2016

# %%
plt.figure(figsize=(19,10))
g = sns.lineplot(data=df_all_top, x="Year", y="CO2/population", hue="Country")

g.set(title='Emissions de CO2 per capita des 10 pays les plus polluants en 2016')
g.title.set_size(30)
g.xaxis.label.set_size(16)
g.yaxis.label.set_size(16)
g.legend(fontsize=50)
g.legend(fontsize="larger")
g.legend(loc='center left',bbox_to_anchor=(1, 0.5))
g.grid()
g.tick_params(axis='x',which='minor',direction='out',bottom=True,length=5)
g.set_xticklabels(labels,  rotation=90, 
    horizontalalignment='center',
    fontweight='light',
    fontsize='x-large')
g.set_yticklabels(labelsy.astype(int),
    fontweight='light',
    fontsize='x-large')
# Out:
# [Text(0, 0, '151645'),
#  Text(0, 0, '162624'),
#  Text(0, 0, '179019'),
#  Text(0, 0, '194453'),
#  Text(0, 0, '191982'),
#  Text(0, 0, '209767'),
#  Text(0, 0, '216364'),
#  Text(0, 0, '219829')]

# %%
plt.figure(figsize=(19,10))
g = sns.lineplot(data=df_all_top, x="Year", y="CO2", hue="Country")

g.set(title='Emissions de CO2 des 10 pays les plus polluants en 2016')
g.title.set_size(30)
g.xaxis.label.set_size(16)
g.yaxis.label.set_size(16)
g.legend(fontsize=50)
g.legend(fontsize="larger")
g.legend(loc='center left',bbox_to_anchor=(1, 0.5))
g.grid()
g.tick_params(axis='x',which='minor',direction='out',bottom=True,length=5)
g.set_xticklabels(labels,  rotation=90, 
    horizontalalignment='center',
    fontweight='light',
    fontsize='x-large')
g.set_yticklabels(labelsy.astype(int),
    fontweight='light',
    fontsize='x-large')
# Out:
# [Text(0, 0, '151645'),
#  Text(0, 0, '162624'),
#  Text(0, 0, '179019'),
#  Text(0, 0, '194453'),
#  Text(0, 0, '191982'),
#  Text(0, 0, '209767'),
#  Text(0, 0, '216364'),
#  Text(0, 0, '219829')]
