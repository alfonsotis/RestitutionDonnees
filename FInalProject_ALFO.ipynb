# %% [markdown]
# # Importer données

# %%
import pandas
import numpy as np
import statistics
import scipy.stats as stats
# pip install seaborn
import seaborn as sns
# pip install matplotlib
# %matplotlib inline
import matplotlib as plt
import matplotlib.pyplot as plt
import pandas as pd

# %%
df1 = pd.read_csv("C:/Users/alfon/Documents/ESGI/Reporting et Restitution/projetFinal/CO2/CO2.csv", sep=",")
df2 = pd.read_csv("C:/Users/alfon/Documents/ESGI/Reporting et Restitution/projetFinal/CO2/CO2metadata.csv", sep=",")
df_pib = pd.read_csv("C:/Users/alfon/Documents/ESGI/Reporting et Restitution/projetFinal/PIB/pib.csv")
df_srf = pd.read_csv("C:/Users/alfon/Documents/ESGI/Reporting et Restitution/projetFinal/SRF/srf.csv")
df_pop = pd.read_csv("C:/Users/alfon/Documents/ESGI/Reporting et Restitution/projetFinal/POP/pop.csv")
df_en_renew = pd.read_csv("C:/Users/alfon/Documents/ESGI/Reporting et Restitution/gitProject/RestitutionDonnees/ENERGIES_RENOUVELABLES/EN_RENEW.csv")
df_carbon = pd.read_csv("C:/Users/alfon/Documents/ESGI/Reporting et Restitution/gitProject/RestitutionDonnees/CONSOMMATION_CHARBON/CONS_CHARB.csv")
df_energy_use_capita = pd.read_csv("C:/Users/alfon/Documents/ESGI/Reporting et Restitution/gitProject/RestitutionDonnees/energy-use-per-capita/energy-use-capita.csv")

# %% [markdown]
# ## Le dataset CO2.csv contenait des agrégations tels que "word", "pays ocde", etc,  qui ont été supprimés du fichier pour ne pas considérer des doublons

# %%
df_carbon.head()
# Out:
#   Country Name Country Code  \
# 0        Aruba          ABW
# 1          NaN          AFE
# 2  Afghanistan          AFG
# 3          NaN          AFW
# 4       Angola          AGO
#
#                                       Indicator Name     Indicator Code  \
# 0  Émissions de CO2 attribuables à la consommatio...  EN.ATM.CO2E.SF.ZS
# 1  Émissions de CO2 attribuables à la consommatio...  EN.ATM.CO2E.SF.ZS
# 2  Émissions de CO2 attribuables à la consommatio...  EN.ATM.CO2E.SF.ZS
# 3  Émissions de CO2 attribuables à la consommatio...  EN.ATM.CO2E.SF.ZS
# 4  Émissions de CO2 attribuables à la consommatio...  EN.ATM.CO2E.SF.ZS
#
#         1960       1961       1962       1963       1964       1965  ...  \
# 0   0.000000   0.000000   0.000000   0.000000   0.000000   0.000000  ...
# 1  82.898414  82.135139  81.540091  81.208316  79.035536  79.527407  ...
# 2  30.973451  35.820896  43.085106  37.305699  35.807860  37.818182  ...
# 3  18.794475  17.755182  17.862538  13.441373  13.214473   9.876087  ...
# 4  22.666667  13.709677   7.763975   1.910828   6.287425   4.629630  ...
#
#         2011       2012       2013       2014       2015       2016  2017  \
# 0        NaN        NaN        NaN        NaN        NaN        NaN   NaN
# 1  78.592773  74.480709  71.663847  72.979637  70.246113  71.736710   NaN
# 2  35.114666  35.090909  46.322268  56.061434  49.750038  65.351001   NaN
# 3   0.780213   0.732431   0.666588   0.927653   1.031379   1.296756   NaN
# 4   0.000000   0.000000   0.000000   0.000000   0.000000   0.000000   NaN
#
#    2018  2019  2020
# 0   NaN   NaN   NaN
# 1   NaN   NaN   NaN
# 2   NaN   NaN   NaN
# 3   NaN   NaN   NaN
# 4   NaN   NaN   NaN
#
# [5 rows x 65 columns]

# %%
df_energy_use_capita.drop(["Country Code", "Indicator Name", "Indicator Code"], axis=1, inplace=True)
df_energy_use_capita.head()
# Out:
#                   Country Name  1960  1961  1962  1963  1964  1965  1966  \
# 0                        Aruba   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1  Africa Eastern and Southern   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2                  Afghanistan   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3   Africa Western and Central   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4                       Angola   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#    1967  1968  ...        2011        2012        2013        2014  2015  \
# 0   NaN   NaN  ...         NaN         NaN         NaN         NaN   NaN
# 1   NaN   NaN  ...  749.402188  728.721222  725.668196  740.766343   NaN
# 2   NaN   NaN  ...         NaN         NaN         NaN         NaN   NaN
# 3   NaN   NaN  ...  610.016077  624.240458  622.117525  611.437410   NaN
# 4   NaN   NaN  ...  521.780703  552.363766  533.760887  544.609443   NaN
#
#    2016  2017  2018  2019  2020
# 0   NaN   NaN   NaN   NaN   NaN
# 1   NaN   NaN   NaN   NaN   NaN
# 2   NaN   NaN   NaN   NaN   NaN
# 3   NaN   NaN   NaN   NaN   NaN
# 4   NaN   NaN   NaN   NaN   NaN
#
# [5 rows x 62 columns]

# %%
df_en_renew.head()
# Out:
#   Country Name Country Code  \
# 0        Aruba          ABW
# 1  Afghanistan          AFG
# 2       Angola          AGO
# 3      Albanie          ALB
# 4      Andorre          AND
#
#                                       Indicator Name  Indicator Code  1960  \
# 0  Consommation d’énergies renouvelables (% de la...  EG.FEC.RNEW.ZS   NaN
# 1  Consommation d’énergies renouvelables (% de la...  EG.FEC.RNEW.ZS   NaN
# 2  Consommation d’énergies renouvelables (% de la...  EG.FEC.RNEW.ZS   NaN
# 3  Consommation d’énergies renouvelables (% de la...  EG.FEC.RNEW.ZS   NaN
# 4  Consommation d’énergies renouvelables (% de la...  EG.FEC.RNEW.ZS   NaN
#
#    1961  1962  1963  1964  1965  ...       2011       2012       2013  \
# 0   NaN   NaN   NaN   NaN   NaN  ...   5.661788   6.855850   6.889753
# 1   NaN   NaN   NaN   NaN   NaN  ...  11.482706  13.973586  16.334293
# 2   NaN   NaN   NaN   NaN   NaN  ...  52.715679  52.245736  50.686116
# 3   NaN   NaN   NaN   NaN   NaN  ...  35.962532  40.048300  41.288974
# 4   NaN   NaN   NaN   NaN   NaN  ...  18.971546  19.195529  19.563698
#
#         2014       2015  2016  2017  2018  2019  2020
# 0   6.927502   6.726748   NaN   NaN   NaN   NaN   NaN
# 1  19.314269  18.423477   NaN   NaN   NaN   NaN   NaN
# 2  50.797461  49.568210   NaN   NaN   NaN   NaN   NaN
# 3  38.689501  38.615210   NaN   NaN   NaN   NaN   NaN
# 4  19.886323  19.747809   NaN   NaN   NaN   NaN   NaN
#
# [5 rows x 65 columns]

# %%
df_en_renew.drop(["Country Code", "Indicator Name", "Indicator Code"], axis=1, inplace=True)

# %%
df_carbon.drop(["Country Code", "Indicator Name", "Indicator Code"], axis=1, inplace=True)

# %%
df_en_renew.head()
# Out:
#   Country Name  1960  1961  1962  1963  1964  1965  1966  1967  1968  ...  \
# 0        Aruba   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 1  Afghanistan   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 2       Angola   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 3      Albanie   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 4      Andorre   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
#
#         2011       2012       2013       2014       2015  2016  2017  2018  \
# 0   5.661788   6.855850   6.889753   6.927502   6.726748   NaN   NaN   NaN
# 1  11.482706  13.973586  16.334293  19.314269  18.423477   NaN   NaN   NaN
# 2  52.715679  52.245736  50.686116  50.797461  49.568210   NaN   NaN   NaN
# 3  35.962532  40.048300  41.288974  38.689501  38.615210   NaN   NaN   NaN
# 4  18.971546  19.195529  19.563698  19.886323  19.747809   NaN   NaN   NaN
#
#    2019  2020
# 0   NaN   NaN
# 1   NaN   NaN
# 2   NaN   NaN
# 3   NaN   NaN
# 4   NaN   NaN
#
# [5 rows x 62 columns]

# %%
energy_use_Ger = df_energy_use_capita[df_energy_use_capita["Country Name"] == "Germany"]
energy_use_Chine = df_energy_use_capita[df_energy_use_capita["Country Name"] == "China"]

# %%
carb_Germay = df_carbon[df_carbon["Country Name"] == "Allemagne"]
renew_Germany = df_en_renew[df_en_renew["Country Name"] == "Allemagne"]
# df_all[df_all["Country"]=="Germany"] 
renew_Chine = df_en_renew[df_en_renew["Country Name"] == "Chine"]
carb_China = df_carbon[df_carbon["Country Name"] == "Chine"]
renew_Germany
renew_Chine
# Out:
#    Country Name Country Code  \
# 36        Chine          CHN
#
#                                        Indicator Name  Indicator Code  1960  \
# 36  Consommation d’énergies renouvelables (% de la...  EG.FEC.RNEW.ZS   NaN
#
#     1961  1962  1963  1964  1965  ...       2011       2012       2013  \
# 36   NaN   NaN   NaN   NaN   NaN  ...  11.695797  11.968567  11.838167
#
#          2014       2015  2016  2017  2018  2019  2020
# 36  12.223823  12.413353   NaN   NaN   NaN   NaN   NaN
#
# [1 rows x 65 columns]

# %%
df_enegy_chine_melt = energy_use_Chine.melt(id_vars=["Country Name"])
df_enegy_germa_melt = energy_use_Ger.melt(id_vars=["Country Name"])
df_enegy_germa_melt.columns = ["Country", "Year", "value"]
df_enegy_chine_melt.columns = ["Country", "Year", "value"]

# %%
print(df_enegy_chine_melt)
# Out:
#    Country  Year  value
# 0    China  1960    NaN
# 1    China  1961    NaN
# 2    China  1962    NaN
# 3    China  1963    NaN
# 4    China  1964    NaN
# ..     ...   ...    ...
# 56   China  2016    NaN
# 57   China  2017    NaN
# 58   China  2018    NaN
# 59   China  2019    NaN
# 60   China  2020    NaN
#
# [61 rows x 3 columns]

# %%
plt.figure(figsize=(25,10))
g = sns.lineplot(data=df_enegy_germa_melt, x="Year", y="value", hue="Country")
# labels = df_Chine_melt["Year"].unique()
# labelsy= df_Chine_melt["value"].unique()
# # g.set_xticks(len(labels))
g.set(title='Germany consomation energy per capita')
g.title.set_size(40)
g.xaxis.label.set_size(16)
g.yaxis.label.set_size(16)
#g.legend(fontsize=500) # using a size in points
g.legend(fontsize="larger")
g.legend(loc='center left',bbox_to_anchor=(1, 0.5))
g.grid()
# g.tick_params(axis='x',which='minor',direction='out',bottom=True,length=5)
# g.set_xticklabels(labels,  rotation=90, 
#     horizontalalignment='center',
#     fontweight='light',
#     fontsize='xx-large')
# g.set_yticklabels(labelsy,
#     fontweight='light',
#     fontsize='xx-large')

# %%
plt.figure(figsize=(25,10))
g = sns.lineplot(data=df_enegy_chine_melt, x="Year", y="value", hue="Country")
# labels = df_Chine_melt["Year"].unique()
# labelsy= df_Chine_melt["value"].unique()
# # g.set_xticks(len(labels))
g.set(title='China consomation energy per capita')
g.title.set_size(40)
g.xaxis.label.set_size(16)
g.yaxis.label.set_size(16)
#g.legend(fontsize=500) # using a size in points
g.legend(fontsize="larger")
g.legend(loc='center left',bbox_to_anchor=(1, 0.5))
g.grid()
# g.tick_params(axis='x',which='minor',direction='out',bottom=True,length=5)
# g.set_xticklabels(labels,  rotation=90, 
#     horizontalalignment='center',
#     fontweight='light',
#     fontsize='xx-large')
# g.set_yticklabels(labelsy,
#     fontweight='light',
#     fontsize='xx-large')

# %%
df_carb_Germ_melt = carb_Germay.melt(id_vars=["Country Name"])
df_Germ_melt = renew_Germany.melt(id_vars=["Country Name"])
df_Germ_melt.columns = ["Country", "Year", "value"]
df_carb_Germ_melt.columns = ["Country", "Year", "value"]
print(df_Germ_melt.shape)

df_carb_Chine_melt = carb_China.melt(id_vars=["Country Name"])
df_Chine_melt = renew_Chine.melt(id_vars=["Country Name"])
df_Chine_melt.columns = ["Country", "Year", "value"]
df_carb_Chine_melt.columns = ["Country", "Year", "value"]
print(df_Chine_melt.shape)
# Out:
# (61, 3)
# (61, 3)

# %%
df_carb_Chine_melt
# Out:
#    Country  Year      value
# 0    Chine  1960  95.934826
# 1    Chine  1961  94.717370
# 2    Chine  1962  93.619626
# 3    Chine  1963  93.075709
# 4    Chine  1964  91.984054
# ..     ...   ...        ...
# 56   Chine  2016  70.831805
# 57   Chine  2017        NaN
# 58   Chine  2018        NaN
# 59   Chine  2019        NaN
# 60   Chine  2020        NaN
#
# [61 rows x 3 columns]

# %%
plt.figure(figsize=(25,10))
g = sns.lineplot(data=df_carb_Chine_melt, x="Year", y="value", hue="Country")
# labels = df_Chine_melt["Year"].unique()
# labelsy= df_Chine_melt["value"].unique()
# # g.set_xticks(len(labels))
g.set(title='China emssions de CO2 du au charbon (%)')
g.title.set_size(40)
g.xaxis.label.set_size(16)
g.yaxis.label.set_size(16)
#g.legend(fontsize=500) # using a size in points
g.legend(fontsize="larger")
g.legend(loc='center left',bbox_to_anchor=(1, 0.5))
g.grid()
# g.tick_params(axis='x',which='minor',direction='out',bottom=True,length=5)
# g.set_xticklabels(labels,  rotation=90, 
#     horizontalalignment='center',
#     fontweight='light',
#     fontsize='xx-large')
# g.set_yticklabels(labelsy,
#     fontweight='light',
#     fontsize='xx-large')

# %%
plt.figure(figsize=(25,10))
g = sns.lineplot(data=df_carb_Germ_melt, x="Year", y="value", hue="Country")
# labels = df_Chine_melt["Year"].unique()
# labelsy= df_Chine_melt["value"].unique()
# # g.set_xticks(len(labels))
g.set(title='Germany emssions en carbon (%)')
g.title.set_size(40)
g.xaxis.label.set_size(16)
g.yaxis.label.set_size(16)
#g.legend(fontsize=500) # using a size in points
g.legend(fontsize="larger")
g.legend(loc='center left',bbox_to_anchor=(1, 0.5))
g.grid()
# g.tick_params(axis='x',which='minor',direction='out',bottom=True,length=5)
# g.set_xticklabels(labels,  rotation=90, 
#     horizontalalignment='center',
#     fontweight='light',
#     fontsize='xx-large')
# g.set_yticklabels(labelsy,
#     fontweight='light',
#     fontsize='xx-large')

# %%
carb_china_alemania = pd.concat([df_carb_Germ_melt, df_carb_Chine_melt])

# %%
plt.figure(figsize=(25,10))
g = sns.lineplot(data=carb_china_alemania, x="Year", y="value", hue="Country")
# labels = df_Chine_melt["Year"].unique()
# labelsy= df_Chine_melt["value"].unique()
# # g.set_xticks(len(labels))
g.set(title='China vs Germany use of carbon energy (%)')
g.title.set_size(40)
g.xaxis.label.set_size(16)
g.yaxis.label.set_size(16)
#g.legend(fontsize=500) # using a size in points
g.legend(fontsize="larger")
g.legend(loc='center left',bbox_to_anchor=(1, 0.5))
g.grid()
# g.tick_params(axis='x',which='minor',direction='out',bottom=True,length=5)
# g.set_xticklabels(labels,  rotation=90, 
#     horizontalalignment='center',
#     fontweight='light',
#     fontsize='xx-large')
# g.set_yticklabels(labelsy,
#     fontweight='light',
#     fontsize='xx-large')

# %%
df_Germ_melt['value'].unique()
# Out:
# array([        nan,  2.09803377,  1.98863281,  2.06262189,  2.11093109,
#         2.26620206,  2.319749  ,  2.25217383,  2.82442182,  3.04511891,
#         3.26371215,  3.70043759,  3.89967279,  4.41263679,  5.05846742,
#         5.82524443,  6.76455101,  7.75322466,  9.4065879 ,  8.59224826,
#         9.63006157, 10.29351964, 11.39435591, 12.01513573, 12.08907875,
#        13.37887823, 14.2062527 ])

# %%
df_Chine_melt['value'].unique()
# Out:
# array([        nan, 34.08361405, 33.25847354, 32.9312779 , 31.6777918 ,
#        31.24948417, 29.47211139, 30.53717546, 30.18348168, 29.73990148,
#        30.50604898, 29.73071484, 28.45581538, 27.09820152, 23.94657959,
#        20.24947926, 18.20381865, 17.09461008, 15.34937114, 14.60199657,
#        13.91196227, 12.88431031, 11.69579699, 11.96856703, 11.8381669 ,
#        12.22382301, 12.41335257])

# %%
df_Chine_melt["value"].unique()
# Out:
# array([        nan, 34.08361405, 33.25847354, 32.9312779 , 31.6777918 ,
#        31.24948417, 29.47211139, 30.53717546, 30.18348168, 29.73990148,
#        30.50604898, 29.73071484, 28.45581538, 27.09820152, 23.94657959,
#        20.24947926, 18.20381865, 17.09461008, 15.34937114, 14.60199657,
#        13.91196227, 12.88431031, 11.69579699, 11.96856703, 11.8381669 ,
#        12.22382301, 12.41335257])

# %%
renew_china_alemania = pd.concat([df_Chine_melt, df_Germ_melt])
renew_china_alemania
# Out:
#       Country  Year  value
# 0       Chine  1960    NaN
# 1       Chine  1961    NaN
# 2       Chine  1962    NaN
# 3       Chine  1963    NaN
# 4       Chine  1964    NaN
# ..        ...   ...    ...
# 56  Allemagne  2016    NaN
# 57  Allemagne  2017    NaN
# 58  Allemagne  2018    NaN
# 59  Allemagne  2019    NaN
# 60  Allemagne  2020    NaN
#
# [122 rows x 3 columns]

# %%
plt.figure(figsize=(25,10))
g = sns.lineplot(data=renew_china_alemania, x="Year", y="value", hue="Country")
# labels = df_Chine_melt["Year"].unique()
# labelsy= df_Chine_melt["value"].unique()
# # g.set_xticks(len(labels))
g.set(title='China vs Germany use of renewable energy (%)')
g.title.set_size(40)
g.xaxis.label.set_size(16)
g.yaxis.label.set_size(16)
#g.legend(fontsize=500) # using a size in points
g.legend(fontsize="larger")
g.legend(loc='center left',bbox_to_anchor=(1, 0.5))
g.grid()
# g.tick_params(axis='x',which='minor',direction='out',bottom=True,length=5)
# g.set_xticklabels(labels,  rotation=90, 
#     horizontalalignment='center',
#     fontweight='light',
#     fontsize='xx-large')
# g.set_yticklabels(labelsy,
#     fontweight='light',
#     fontsize='xx-large')

# %%
plt.figure(figsize=(25,10))
g = sns.lineplot(data=df_Germ_melt, x="Year", y="value")
# labels = df_Germ_melt["Year"].unique()
# labelsy= df_Germ_melt["value"].unique()
# # g.set_xticks(len(labels))
g.set(title='Germany use of renewable energy (%)')
g.title.set_size(40)
g.xaxis.label.set_size(16)
g.yaxis.label.set_size(16)
#g.legend(fontsize=500) # using a size in points
g.legend(fontsize="larger")
g.legend(loc='center left',bbox_to_anchor=(1, 0.5))
g.grid()
# g.tick_params(axis='x',which='minor',direction='out',bottom=True,length=5)
# g.set_xticklabels(labels,  rotation=90, 
#     horizontalalignment='center',
#     fontweight='light',
#     fontsize='x-large')
# g.set_yticklabels(labelsy.astype(int),
#     fontweight='light',
#     fontsize='x-large')
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.

# %%
df1["Country Name"].unique()
# Out:
# array(['China', 'United States', 'India', 'Russian Federation', 'Japan',
#        'Germany', 'Iran, Islamic Rep.', 'Korea, Rep.', 'Saudi Arabia',
#        'Indonesia', 'Canada', 'Mexico', 'South Africa', 'Brazil',
#        'United Kingdom', 'Australia', 'Turkey', 'Poland', 'Thailand',
#        'Malaysia', 'Kazakhstan', 'Spain', 'Egypt, Arab Rep.',
#        'United Arab Emirates', 'Ukraine', 'Argentina', 'Pakistan',
#        'Vietnam', 'Iraq', 'Netherlands', 'Venezuela, RB', 'Algeria',
#        'Philippines', 'Nigeria', 'Qatar', 'Czech Republic', 'Kuwait',
#        'Colombia', 'Belgium', 'Uzbekistan', 'Chile', 'Bangladesh',
#        'Turkmenistan', 'Romania', 'Israel', 'Oman', 'Greece', 'Austria',
#        'Morocco', 'Belarus', 'Peru', 'Libya', 'Portugal', 'Finland',
#        'Hungary', 'Serbia', 'Trinidad and Tobago', 'Hong Kong SAR, China',
#        'Sweden', 'Bulgaria', 'Ecuador', 'Norway', 'Ireland', 'Azerbaijan',
#        'Singapore', 'Angola', 'Switzerland', 'New Zealand',
#        'Slovak Republic', 'Denmark', 'Bahrain', 'Tunisia',
#        'Syrian Arab Republic', 'Cuba', "Korea, Dem. People's Rep.",
#        'Mongolia', 'Myanmar', 'Dominican Republic', 'Jordan', 'Lebanon',
#        'Sri Lanka', 'Bosnia and Herzegovina', 'Bolivia', 'Sudan', 'Kenya',
#        'Lao PDR', 'Croatia', 'Guatemala', 'Ghana', 'Estonia', 'Ethiopia',
#        'Lithuania', 'Slovenia', 'Tanzania', 'Zimbabwe', 'Senegal',
#        'Panama', 'Yemen, Rep.', 'Georgia', 'Cambodia', 'Honduras',
#        'Kyrgyz Republic', "Cote d'Ivoire", 'Nepal', 'Luxembourg',
#        'Kosovo', 'Afghanistan', 'Cameroon', 'Jamaica', 'Costa Rica',
#        'Mozambique', 'Brunei Darussalam', 'Papua New Guinea', 'Paraguay',
#        'El Salvador', 'North Macedonia', 'Latvia', 'Uruguay', 'Cyprus',
#        'Benin', 'Botswana', 'Uganda', 'Equatorial Guinea', 'Nicaragua',
#        'Curacao', 'New Caledonia', 'Gabon', 'Tajikistan', 'Armenia',
#        'Zambia', 'Moldova', 'Albania', 'Mauritius', 'Namibia',
#        'Madagascar', 'Burkina Faso', 'Pacific island small states',
#        'Congo, Rep.', 'West Bank and Gaza', 'Mali', 'Togo', 'Guinea',
#        'Haiti', 'Mauritania', 'Lesotho', 'Guyana', 'Macao SAR, China',
#        'Iceland', 'Fiji', 'Congo, Dem. Rep.', 'Montenegro', 'Niger',
#        'Bahamas, The', 'Suriname', 'South Sudan', 'Maldives', 'Liberia',
#        'Malta', 'Malawi', 'Barbados', 'Bhutan', 'Eswatini', 'Rwanda',
#        'Sierra Leone', 'Chad', 'Aruba', 'French Polynesia', 'Eritrea',
#        'Somalia', 'Gibraltar', 'Faroe Islands', 'Djibouti', 'Bermuda',
#        'Seychelles', 'Belize', 'Antigua and Barbuda', 'Cayman Islands',
#        'Cabo Verde', 'Gambia, The', 'Greenland', 'Burundi', 'Timor-Leste',
#        'Andorra', 'St. Lucia', 'Central African Republic',
#        'Guinea-Bissau', 'Grenada', 'Samoa', 'St. Kitts and Nevis',
#        'Palau', 'St. Vincent and the Grenadines',
#        'Turks and Caicos Islands', 'British Virgin Islands', 'Comoros',
#        'Dominica', 'Solomon Islands', 'Vanuatu', 'Micronesia, Fed. Sts.',
#        'Marshall Islands', 'Tonga', 'Sao Tome and Principe', 'Kiribati',
#        'Liechtenstein', 'Nauru', 'Tuvalu', 'American Samoa',
#        'Channel Islands', 'France', 'Guam', 'Isle of Man', 'Italy',
#        'St. Martin (French part)', 'Monaco', 'Northern Mariana Islands',
#        'Puerto Rico', 'San Marino', 'Sint Maarten (Dutch part)',
#        'Virgin Islands (U.S.)'], dtype=object)

# %%
df_pop.head(2)
# Out:
#   Country Name Country Code     Indicator Name Indicator Code       1960  \
# 0        Aruba          ABW  Population, total    SP.POP.TOTL    54211.0
# 1  Afghanistan          AFG  Population, total    SP.POP.TOTL  8996973.0
#
#         1961       1962       1963       1964       1965  ...        2010  \
# 0    55438.0    56225.0    56695.0    57032.0    57360.0  ...    101669.0
# 1  9169410.0  9351441.0  9543205.0  9744781.0  9956320.0  ...  29185507.0
#
#          2011        2012        2013        2014        2015        2016  \
# 0    102046.0    102560.0    103159.0    103774.0    104341.0    104872.0
# 1  30117413.0  31161376.0  32269589.0  33370794.0  34413603.0  35383128.0
#
#          2017        2018        2019
# 0    105366.0    105845.0    106314.0
# 1  36296400.0  37172386.0  38041754.0
#
# [2 rows x 64 columns]

# %%
df_pop.drop(["Country Name", "Indicator Name", "Indicator Code"], axis=1, inplace=True)

# %% [markdown]
# ## On conserve la surface de 2018

# %%
df_srf = df_srf[["Country Code", "2018"]]

# %%
df_pib.drop(["Country Name", "Indicator Name", "Indicator Code"], axis=1, inplace=True)

# %%
df1.head(2)
# Out:
#     Country Name Country Code      Indicator Name  Indicator Code  \
# 0          China          CHN  CO2 emissions (kt)  EN.ATM.CO2E.KT
# 1  United States          USA  CO2 emissions (kt)  EN.ATM.CO2E.KT
#
#           1960         1961         1962         1963         1964  \
# 0   780726.302   552066.850   440359.029   436695.696   436923.050
# 1  2890696.100  2880505.507  2987207.873  3119230.874  3255995.306
#
#           1965  ...         2007         2008         2009         2010  \
# 0   475972.933  ...  6697654.489  7553070.247  7557789.676  8776040.416
# 1  3390922.571  ...  5789030.561  5614110.994  5263505.457  5395532.125
#
#           2011          2012         2013          2014          2015  \
# 0  9733538.120  1.002857e+07  10258007.13  1.029193e+07  1.014500e+07
# 1  5270047.385  5.082000e+06   5170359.99  5.225413e+06  5.126913e+06
#
#           2016
# 0  9893037.952
# 1  5006302.077
#
# [2 rows x 61 columns]

# %%
df2.head(2)
# Out:
#   Country Code                     Region  IncomeGroup SpecialNotes  \
# 0          ABW  Latin America & Caribbean  High income          NaN
# 1          AFG                 South Asia   Low income          NaN
#
#      TableName  Unnamed: 5
# 0        Aruba         NaN
# 1  Afghanistan         NaN

# %%
print(df1.shape)
print(df2.shape)
# Out:
# (218, 61)
# (263, 6)

# %% [markdown]
# ## Merge pour avoir Region et Income groupe dans le même dataFrame

# %%
df_co2 = df1.merge(df2, how="left", on="Country Code")
print(df_co2.shape)
# Out:
# (218, 66)

# %%
df_co2.head(2)
# Out:
#     Country Name Country Code      Indicator Name  Indicator Code  \
# 0          China          CHN  CO2 emissions (kt)  EN.ATM.CO2E.KT
# 1  United States          USA  CO2 emissions (kt)  EN.ATM.CO2E.KT
#
#           1960         1961         1962         1963         1964  \
# 0   780726.302   552066.850   440359.029   436695.696   436923.050
# 1  2890696.100  2880505.507  2987207.873  3119230.874  3255995.306
#
#           1965  ...          2012         2013          2014          2015  \
# 0   475972.933  ...  1.002857e+07  10258007.13  1.029193e+07  1.014500e+07
# 1  3390922.571  ...  5.082000e+06   5170359.99  5.225413e+06  5.126913e+06
#
#           2016               Region          IncomeGroup  \
# 0  9893037.952  East Asia & Pacific  Upper middle income
# 1  5006302.077        North America          High income
#
#                                         SpecialNotes      TableName  \
# 0  On 1 July 1997 China resumed its exercise of s...          China
# 1                                                NaN  United States
#
#    Unnamed: 5
# 0         NaN
# 1         NaN
#
# [2 rows x 66 columns]

# %%
print(df_co2["Indicator Name"].unique())
# Out:
# ['CO2 emissions (kt)']

# %%
df_co2 = df_co2.drop('Indicator Name', 1)
df_co2 = df_co2.drop('Indicator Code', 1)
df_co2 = df_co2.drop('Unnamed: 5', 1)
df_co2 = df_co2.drop('TableName', 1)
df_co2 = df_co2.drop('SpecialNotes', 1)

# %%
df_co2 = df_co2.sort_values(by="Country Name")

# %%
df_co2.head()
# Out:
#        Country Name Country Code      1960      1961      1962      1963  \
# 106     Afghanistan          AFG   414.371   491.378   689.396   707.731
# 131         Albania          ALB  2024.184  2280.874  2464.224  2082.856
# 31          Algeria          DZA  6160.560  6065.218  5669.182  5427.160
# 205  American Samoa          ASM       NaN       NaN       NaN       NaN
# 182         Andorra          AND       NaN       NaN       NaN       NaN
#
#          1964      1965      1966      1967  ...        2009        2010  \
# 106   839.743  1008.425  1092.766  1283.450  ...    6769.282    8463.436
# 131  2016.850  2174.531  2552.232  2680.577  ...    4378.398    4598.418
# 31   5650.847  6596.933  8430.433  8441.434  ...  121399.702  119177.500
# 205       NaN       NaN       NaN       NaN  ...         NaN         NaN
# 182       NaN       NaN       NaN       NaN  ...     517.047     517.047
#
#            2011        2012        2013        2014        2015        2016  \
# 106   12240.446   10755.311    9050.156    8467.103    9035.488    8672.455
# 131    5240.143    4924.781    4913.780    5489.499    4616.753    4536.079
# 31   121187.016  129987.816  134465.223  145411.218  153133.920  150005.969
# 205         NaN         NaN         NaN         NaN         NaN         NaN
# 182     491.378     487.711     476.710     462.042     465.709     469.376
#
#                          Region          IncomeGroup
# 106                  South Asia           Low income
# 131       Europe & Central Asia  Upper middle income
# 31   Middle East & North Africa  Lower middle income
# 205         East Asia & Pacific  Upper middle income
# 182       Europe & Central Asia          High income
#
# [5 rows x 61 columns]

# %% [markdown]
# ## Transposition des donnees

# %%
df_co2_melt = df_co2.melt(id_vars=["Country Name", "Country Code", "Region","IncomeGroup"])

# %%
df_co2_melt.head()
# Out:
#      Country Name Country Code                      Region  \
# 0     Afghanistan          AFG                  South Asia
# 1         Albania          ALB       Europe & Central Asia
# 2         Algeria          DZA  Middle East & North Africa
# 3  American Samoa          ASM         East Asia & Pacific
# 4         Andorra          AND       Europe & Central Asia
#
#            IncomeGroup variable     value
# 0           Low income     1960   414.371
# 1  Upper middle income     1960  2024.184
# 2  Lower middle income     1960  6160.560
# 3  Upper middle income     1960       NaN
# 4          High income     1960       NaN

# %%
df_co2_melt.columns = ["Country", "Country Code", "Region", "IncomeGroup", "Year", "CO2"]

# %%
df_co2_melt = df_co2_melt.sort_values(by=["Country", "Year"])

# %%
df_co2_melt.head()
# Out:
#          Country Country Code      Region IncomeGroup  Year      CO2
# 0    Afghanistan          AFG  South Asia  Low income  1960  414.371
# 218  Afghanistan          AFG  South Asia  Low income  1961  491.378
# 436  Afghanistan          AFG  South Asia  Low income  1962  689.396
# 654  Afghanistan          AFG  South Asia  Low income  1963  707.731
# 872  Afghanistan          AFG  South Asia  Low income  1964  839.743

# %%
df_co2_melt['CO2_Region_Year'] = df_co2_melt.groupby(['Region', 'Year'])["CO2"].transform('sum')

# %%
df_co2_melt['CO2_IncomeGroup_Year'] = df_co2_melt.groupby(['IncomeGroup', 'Year'])["CO2"].transform('sum')

# %%
df_co2_melt.head(20)
# Out:
#           Country Country Code      Region IncomeGroup  Year       CO2  \
# 0     Afghanistan          AFG  South Asia  Low income  1960   414.371
# 218   Afghanistan          AFG  South Asia  Low income  1961   491.378
# 436   Afghanistan          AFG  South Asia  Low income  1962   689.396
# 654   Afghanistan          AFG  South Asia  Low income  1963   707.731
# 872   Afghanistan          AFG  South Asia  Low income  1964   839.743
# 1090  Afghanistan          AFG  South Asia  Low income  1965  1008.425
# 1308  Afghanistan          AFG  South Asia  Low income  1966  1092.766
# 1526  Afghanistan          AFG  South Asia  Low income  1967  1283.450
# 1744  Afghanistan          AFG  South Asia  Low income  1968  1224.778
# 1962  Afghanistan          AFG  South Asia  Low income  1969   942.419
# 2180  Afghanistan          AFG  South Asia  Low income  1970  1672.152
# 2398  Afghanistan          AFG  South Asia  Low income  1971  1895.839
# 2616  Afghanistan          AFG  South Asia  Low income  1972  1532.806
# 2834  Afghanistan          AFG  South Asia  Low income  1973  1639.149
# 3052  Afghanistan          AFG  South Asia  Low income  1974  1917.841
# 3270  Afghanistan          AFG  South Asia  Low income  1975  2126.860
# 3488  Afghanistan          AFG  South Asia  Low income  1976  1987.514
# 3706  Afghanistan          AFG  South Asia  Low income  1977  2390.884
# 3924  Afghanistan          AFG  South Asia  Low income  1978  2159.863
# 4142  Afghanistan          AFG  South Asia  Low income  1979  2240.537
#
#       CO2_Region_Year  CO2_IncomeGroup_Year
# 0          151645.118             36460.981
# 218        162624.116             39706.276
# 436        179019.273             43934.327
# 654        194453.676             46823.923
# 872        191982.118             51437.009
# 1090       209767.068             61011.546
# 1308       216364.001             66545.049
# 1526       219829.316             72001.545
# 1744       241530.622             83519.592
# 1962       244372.547             92525.744
# 2180       249319.330            102257.962
# 2398       257320.724            140196.744
# 2616       245637.662            120743.309
# 2834       254691.485            129371.760
# 3052       263356.606            136207.048
# 3270       285677.635            142433.614
# 3488       297283.690            146177.621
# 3706       314921.960            151934.811
# 3924       321225.533            147325.392
# 4142       338423.763            159151.467

# %%
df_co2_region_year = df_co2_melt[["Region", "Year", "CO2_Region_Year"]]
print(df_co2_region_year.shape)
# Out:
# (12426, 3)

# %%
df_co2_region_year = df_co2_region_year.drop_duplicates()
print(df_co2_region_year.shape)
# Out:
# (456, 3)

# %%
df_co2_region_year = df_co2_region_year[df_co2_region_year["Region"].notnull()]
print(df_co2_region_year.shape)
# Out:
# (399, 3)

# %%
df_co2_region_year.head(20)
# Out:
#           Region  Year  CO2_Region_Year
# 0     South Asia  1960       151645.118
# 218   South Asia  1961       162624.116
# 436   South Asia  1962       179019.273
# 654   South Asia  1963       194453.676
# 872   South Asia  1964       191982.118
# 1090  South Asia  1965       209767.068
# 1308  South Asia  1966       216364.001
# 1526  South Asia  1967       219829.316
# 1744  South Asia  1968       241530.622
# 1962  South Asia  1969       244372.547
# 2180  South Asia  1970       249319.330
# 2398  South Asia  1971       257320.724
# 2616  South Asia  1972       245637.662
# 2834  South Asia  1973       254691.485
# 3052  South Asia  1974       263356.606
# 3270  South Asia  1975       285677.635
# 3488  South Asia  1976       297283.690
# 3706  South Asia  1977       314921.960
# 3924  South Asia  1978       321225.533
# 4142  South Asia  1979       338423.763

# %%
df_co2_Incomegroup_year = df_co2_melt[["IncomeGroup", "Year", "CO2_IncomeGroup_Year"]]
print(df_co2_Incomegroup_year.shape)
# Out:
# (12426, 3)

# %%
df_co2_Incomegroup_year = df_co2_Incomegroup_year.drop_duplicates()
print(df_co2_Incomegroup_year.shape)
# Out:
# (285, 3)

# %%
df_co2_Incomegroup_year = df_co2_Incomegroup_year[df_co2_Incomegroup_year["IncomeGroup"].notnull()]
print(df_co2_Incomegroup_year.shape)
# Out:
# (228, 3)

# %%
df_co2_Incomegroup_year_pivot = df_co2_Incomegroup_year.pivot("IncomeGroup", "Year", "CO2_IncomeGroup_Year")

# %%
df_co2_Incomegroup_year_pivot.head()
# Out:
# Year                        1960         1961         1962         1963  \
# IncomeGroup
# High income          5163044.325  5277047.688  5527628.466  5838454.387
# Low income             36460.981    39706.276    43934.327    46823.923
# Lower middle income   211160.528   224457.070   246440.735   268362.061
# Upper middle income  2708981.582  2543500.873  2530285.005  2659411.076
#
# Year                        1964         1965         1966         1967  \
# IncomeGroup
# High income          6133424.200  6405790.625  6686547.146  6988542.931
# Low income             51437.009    61011.546    66545.049    72001.545
# Lower middle income   284687.545   313106.795   328071.822   326883.714
# Upper middle income  2818760.561  3008249.119  3209105.377  3265848.535
#
# Year                        1968         1969  ...          2007  \
# IncomeGroup                                    ...
# High income          7361348.486  7843353.634  ...  1.356978e+07
# Low income             83519.592    92525.744  ...  2.013183e+05
# Lower middle income   353737.155   367008.028  ...  2.888210e+06
# Upper middle income  3432121.316  3689918.750  ...  1.252093e+07
#
# Year                         2008          2009          2010          2011  \
# IncomeGroup
# High income          1.339555e+07  1.267893e+07  1.308972e+07  1.285161e+07
# Low income           2.152786e+05  2.000422e+05  1.990301e+05  1.843218e+05
# Lower middle income  3.078791e+06  3.200253e+06  3.316893e+06  3.499128e+06
# Upper middle income  1.367714e+07  1.353731e+07  1.500151e+07  1.623133e+07
#
# Year                         2012          2013          2014          2015  \
# IncomeGroup
# High income          1.278680e+07  1.279028e+07  1.270110e+07  1.200871e+07
# Low income           1.737975e+05  1.668228e+05  1.748096e+05  1.607649e+05
# Lower middle income  3.714345e+06  3.736262e+06  3.982718e+06  4.101459e+06
# Upper middle income  1.670244e+07  1.684622e+07  1.693218e+07  1.683839e+07
#
# Year                         2016
# IncomeGroup
# High income          1.177276e+07
# Low income           1.643183e+05
# Lower middle income  4.229048e+06
# Upper middle income  1.671832e+07
#
# [4 rows x 57 columns]

# %%
df_co2_region_year_pivot = df_co2_region_year.pivot("Region", "Year", "CO2_Region_Year")

# %%
df_co2_region_year_pivot
# Out:
# Year                               1960         1961         1962  \
# Region
# East Asia & Pacific         1202974.018  1039169.128   950919.106
# Europe & Central Asia       3166989.882  3275210.386  3457973.666
# Latin America & Caribbean    297987.754   304911.050   323865.773
# Middle East & North Africa    98634.966   104861.532   114531.411
# North America               3083748.982  3074863.841  3194551.054
# South Asia                   151645.118   162624.116   179019.273
# Sub-Saharan Africa           117666.696   123071.854   127428.250
#
# Year                               1963         1964         1965  \
# Region
# East Asia & Pacific          995212.799  1048960.018  1142956.229
# Europe & Central Asia       3702687.244  3895069.065  4076369.212
# Latin America & Caribbean    323561.412   348911.383   359725.366
# Middle East & North Africa   133046.094   154648.391   184329.089
# North America               3330490.411  3493998.274  3643256.175
# South Asia                   194453.676   191982.118   209767.068
# Sub-Saharan Africa           133599.811   154740.066   171754.946
#
# Year                               1966         1967         1968  \
# Region
# East Asia & Pacific         1234513.885  1243828.065  1381505.580
# Europe & Central Asia       4254640.417  4397913.774  4593672.902
# Latin America & Caribbean    377330.633   406677.634   432240.291
# Middle East & North Africa   210771.826   225010.787   260456.009
# North America               3821399.035  3977818.587  4135118.219
# South Asia                   216364.001   219829.316   241530.622
# Sub-Saharan Africa           175249.597   182198.562   186202.926
#
# Year                               1969  ...          2007          2008  \
# Region                                   ...
# East Asia & Pacific         1609468.302  ...  1.000234e+07  1.094005e+07
# Europe & Central Asia       4831862.887  ...  6.970542e+06  6.958206e+06
# Latin America & Caribbean    470289.083  ...  1.569747e+06  1.656718e+06
# Middle East & North Africa   302333.149  ...  1.928725e+06  2.086633e+06
# North America               4332347.814  ...  6.361607e+06  6.176552e+06
# South Asia                   244372.547  ...  1.629457e+06  1.798176e+06
# Sub-Saharan Africa           202132.374  ...  7.178226e+05  7.504259e+05
#
# Year                                2009          2010          2011  \
# Region
# East Asia & Pacific         1.090385e+07  1.227860e+07  1.335693e+07
# Europe & Central Asia       6.392538e+06  6.690904e+06  6.679151e+06
# Latin America & Caribbean   1.621753e+06  1.706255e+06  1.728818e+06
# Middle East & North Africa  2.184454e+06  2.268890e+06  2.302443e+06
# North America               5.796174e+06  5.923404e+06  5.793266e+06
# South Asia                  1.977507e+06  1.977587e+06  2.106042e+06
# Sub-Saharan Africa          7.402610e+05  7.615149e+05  7.997324e+05
#
# Year                                2012          2013          2014  \
# Region
# East Asia & Pacific         1.372970e+07  1.390204e+07  1.386372e+07
# Europe & Central Asia       6.654355e+06  6.501903e+06  6.273991e+06
# Latin America & Caribbean   1.808487e+06  1.845113e+06  1.870075e+06
# Middle East & North Africa  2.513149e+06  2.492354e+06  2.630361e+06
# North America               5.600088e+06  5.690058e+06  5.766677e+06
# South Asia                  2.286206e+06  2.307900e+06  2.525679e+06
# Sub-Saharan Africa          7.854054e+05  8.002091e+05  8.603039e+05
#
# Year                                2015          2016
# Region
# East Asia & Pacific         1.386268e+07  1.368487e+07
# Europe & Central Asia       5.600213e+06  5.639908e+06
# Latin America & Caribbean   1.851263e+06  1.815792e+06
# Middle East & North Africa  2.648172e+06  2.608737e+06
# North America               5.676901e+06  5.551809e+06
# South Asia                  2.645135e+06  2.736913e+06
# Sub-Saharan Africa          8.249577e+05  8.464133e+05
#
# [7 rows x 57 columns]

# %% [markdown]
# # Analyse Monovarie

# %% [markdown]
# ### Evolution d'emition de CO2 par region

# %%
plt.figure(figsize=(10,5))
h1 =sns.heatmap(df_co2_region_year_pivot, cmap="Blues")
h1.set(title='East Asia & Pacifique est la région la plus polluante')
h1.title.set_size(17)

# %% [markdown]
# ### Evolution des émissions de CO2 par niveau de Income

# %%
plt.figure(figsize=(10,5))
g = sns.heatmap(df_co2_Incomegroup_year_pivot, cmap="Blues")
g.set(title='Les pays riches polluent plus')
g.title.set_size(20)

# %%
df_co2_Incomegroup_year.head(2)
# g.set_xticklabels(g.get_xticklabels(), rotation=30)
# Out:
#     IncomeGroup  Year  CO2_IncomeGroup_Year
# 0    Low income  1960             36460.981
# 218  Low income  1961             39706.276

# %%
plt.figure(figsize=(25,10))
g = sns.lineplot(data=df_co2_Incomegroup_year, x="Year", y="CO2_IncomeGroup_Year", hue="IncomeGroup")
labels = df_co2_Incomegroup_year["Year"].unique()
labelsy=df_co2_Incomegroup_year["CO2_IncomeGroup_Year"].unique()
# g.set_xticks(len(labels))
g.set(title='Les pays riches évoluent plus')
g.title.set_size(40)
g.xaxis.label.set_size(16)
g.yaxis.label.set_size(16)
#g.legend(fontsize=500) # using a size in points
g.legend(fontsize="larger")
g.legend(loc='center left',bbox_to_anchor=(1, 0.5))
g.grid()
g.tick_params(axis='x',which='minor',direction='out',bottom=True,length=5)
g.set_xticklabels(labels,  rotation=90, 
    horizontalalignment='center',
    fontweight='light',
    fontsize='x-large')
g.set_yticklabels(labelsy.astype(int),
    fontweight='light',
    fontsize='x-large')
# Out:
# <ipython-input-334-ff64fd1881f0>:15: UserWarning: FixedFormatter should only be used together with FixedLocator
#   g.set_xticklabels(labels,  rotation=90,
# <ipython-input-334-ff64fd1881f0>:19: UserWarning: FixedFormatter should only be used together with FixedLocator
#   g.set_yticklabels(labelsy.astype(int),
# [Text(0, -2500000.0, '36460'),
#  Text(0, 0.0, '39706'),
#  Text(0, 2500000.0, '43934'),
#  Text(0, 5000000.0, '46823'),
#  Text(0, 7500000.0, '51437'),
#  Text(0, 10000000.0, '61011'),
#  Text(0, 12500000.0, '66545'),
#  Text(0, 15000000.0, '72001'),
#  Text(0, 17500000.0, '83519'),
#  Text(0, 20000000.0, '92525')]

# %%
plt.figure(figsize=(25,10))
g = sns.lineplot(data=df_co2_region_year, x="Year", y="CO2_Region_Year", hue="Region")
labels = df_co2_region_year["Year"].unique()
labelsy=df_co2_region_year["CO2_Region_Year"].unique()
g.set(title='East Asia & Pacific se démarquent du reste du monde')
g.title.set_size(40)
g.xaxis.label.set_size(16)
g.yaxis.label.set_size(16)
g.legend(fontsize=50)
g.legend(fontsize="larger")
g.legend(loc='center left',bbox_to_anchor=(1, 0.5))
g.grid()
g.tick_params(axis='x',which='minor',direction='out',bottom=True,length=5)
g.set_xticklabels(labels,  rotation=90, 
    horizontalalignment='center',
    fontweight='light',
    fontsize='x-large')
g.set_yticklabels(labelsy.astype(int),
    fontweight='light',
    fontsize='x-large')
# Out:
# <ipython-input-335-87a15d753c87>:14: UserWarning: FixedFormatter should only be used together with FixedLocator
#   g.set_xticklabels(labels,  rotation=90,
# <ipython-input-335-87a15d753c87>:18: UserWarning: FixedFormatter should only be used together with FixedLocator
#   g.set_yticklabels(labelsy.astype(int),
# [Text(0, -2000000.0, '151645'),
#  Text(0, 0.0, '162624'),
#  Text(0, 2000000.0, '179019'),
#  Text(0, 4000000.0, '194453'),
#  Text(0, 6000000.0, '191982'),
#  Text(0, 8000000.0, '209767'),
#  Text(0, 10000000.0, '216364'),
#  Text(0, 12000000.0, '219829'),
#  Text(0, 14000000.0, '241530'),
#  Text(0, 16000000.0, '244372')]

# %%
df1['Country Name'] = df1['Country Name'].astype("category")

# %%
df1.dtypes
# Out:
# Country Name      category
# Country Code        object
# Indicator Name      object
# Indicator Code      object
# 1960               float64
#                     ...
# 2012               float64
# 2013               float64
# 2014               float64
# 2015               float64
# 2016               float64
# Length: 61, dtype: object

# %% [raw]
# df1['Country Name'] = df1['Country Name'].cat.as_ordered()
# df1 = df1.set_index('Country Name')

# %%
df_co2.shape
# Out:
# (218, 61)

# %%
df_co2_melt.head(2)
# Out:
#          Country Country Code      Region IncomeGroup  Year      CO2  \
# 0    Afghanistan          AFG  South Asia  Low income  1960  414.371
# 218  Afghanistan          AFG  South Asia  Low income  1961  491.378
#
#      CO2_Region_Year  CO2_IncomeGroup_Year
# 0         151645.118             36460.981
# 218       162624.116             39706.276

# %%
df_pib.head()
# Out:
#   Country Code         1960         1961         1962         1963  \
# 0          ABW          NaN          NaN          NaN          NaN
# 1          AFG  537777811.1  548888895.6  546666677.8  751111191.1
# 2          AGO          NaN          NaN          NaN          NaN
# 3          ALB          NaN          NaN          NaN          NaN
# 4          AND          NaN          NaN          NaN          NaN
#
#           1964          1965          1966          1967          1968  ...  \
# 0          NaN           NaN           NaN           NaN           NaN  ...
# 1  800000044.4  1.006667e+09  1.400000e+09  1.673333e+09  1.373333e+09  ...
# 2          NaN           NaN           NaN           NaN           NaN  ...
# 3          NaN           NaN           NaN           NaN           NaN  ...
# 4          NaN           NaN           NaN           NaN           NaN  ...
#
#            2010          2011          2012          2013          2014  \
# 0  2.390503e+09  2.549721e+09  2.534637e+09  2.701676e+09  2.765363e+09
# 1  1.585657e+10  1.780429e+10  2.000160e+10  2.056107e+10  2.048489e+10
# 2  8.379950e+10  1.117900e+11  1.280530e+11  1.367100e+11  1.457120e+11
# 3  1.192693e+10  1.289077e+10  1.231983e+10  1.277622e+10  1.322814e+10
# 4  3.449967e+09  3.629204e+09  3.188809e+09  3.193704e+09  3.271808e+09
#
#            2015          2016          2017          2018          2019
# 0  2.919553e+09  2.965922e+09  3.056425e+09           NaN           NaN
# 1  1.990711e+10  1.801775e+10  1.886995e+10  1.835388e+10  1.929110e+10
# 2  1.161940e+11  1.011240e+11  1.221240e+11  1.013530e+11  8.881570e+10
# 3  1.138685e+10  1.186120e+10  1.301969e+10  1.514702e+10  1.527918e+10
# 4  2.789870e+09  2.896679e+09  3.000181e+09  3.218316e+09  3.154058e+09
#
# [5 rows x 61 columns]

# %%
df_pib_melt = df_pib.melt(id_vars=["Country Code"])

# %%
df_pib_melt.head()
# Out:
#   Country Code variable        value
# 0          ABW     1960          NaN
# 1          AFG     1960  537777811.1
# 2          AGO     1960          NaN
# 3          ALB     1960          NaN
# 4          AND     1960          NaN

# %%
df_pib_melt.columns = ["Country Code", "Year", "PIB"]

# %%
df_pop_melt = df_pop.melt(id_vars=["Country Code"])

# %%
df_pop_melt.columns = ["Country Code", "Year", "Population"]

# %%
df_pib_melt.head(2)
# Out:
#   Country Code  Year          PIB
# 0          ABW  1960          NaN
# 1          AFG  1960  537777811.1

# %%
df_pop_melt.head(2)
# Out:
#   Country Code  Year  Population
# 0          ABW  1960     54211.0
# 1          AFG  1960   8996973.0

# %%
df_srf.columns = ["Country Code", "Surface"]

# %%
print(df_pib_melt.shape)
df_pib_melt = df_pib_melt.merge(df_srf, how="left", on="Country Code")
print(df_pib_melt.shape)
# Out:
# (15840, 3)
# (15840, 4)

# %%
print(df_pib_melt.shape)
df_pib_melt = df_pib_melt.merge(df_pop_melt, how="left", on=["Country Code", "Year"])
print(df_pib_melt.shape)
# Out:
# (15840, 4)
# (15840, 5)

# %%
print(df_co2_melt.shape)
df_all = df_co2_melt.merge(df_pib_melt, how="left", on=["Country Code", "Year"])
print(df_all.shape)
# Out:
# (12426, 8)
# (12426, 11)

# %%
df_co2_melt.head(2)
# Out:
#          Country Country Code      Region IncomeGroup  Year      CO2  \
# 0    Afghanistan          AFG  South Asia  Low income  1960  414.371
# 218  Afghanistan          AFG  South Asia  Low income  1961  491.378
#
#      CO2_Region_Year  CO2_IncomeGroup_Year
# 0         151645.118             36460.981
# 218       162624.116             39706.276

# %%
df_pib_melt.head(2)
# Out:
#   Country Code  Year          PIB   Surface  Population
# 0          ABW  1960          NaN     180.0     54211.0
# 1          AFG  1960  537777811.1  652860.0   8996973.0

# %%
df_all['PIB/Capita'] = df_all['PIB']/df_all['Population']

# %%
df_all['CO2/Capita'] = df_all['CO2']/df_all['Population']

# %%
df_all['CO2/PIB'] = df_all['CO2']/df_all['PIB']

# %%
df_all.head(100)
# Out:
#         Country Country Code                 Region          IncomeGroup  \
# 0   Afghanistan          AFG             South Asia           Low income
# 1   Afghanistan          AFG             South Asia           Low income
# 2   Afghanistan          AFG             South Asia           Low income
# 3   Afghanistan          AFG             South Asia           Low income
# 4   Afghanistan          AFG             South Asia           Low income
# ..          ...          ...                    ...                  ...
# 95      Albania          ALB  Europe & Central Asia  Upper middle income
# 96      Albania          ALB  Europe & Central Asia  Upper middle income
# 97      Albania          ALB  Europe & Central Asia  Upper middle income
# 98      Albania          ALB  Europe & Central Asia  Upper middle income
# 99      Albania          ALB  Europe & Central Asia  Upper middle income
#
#     Year       CO2  CO2_Region_Year  CO2_IncomeGroup_Year           PIB  \
# 0   1960   414.371       151645.118             36460.981  5.377778e+08
# 1   1961   491.378       162624.116             39706.276  5.488889e+08
# 2   1962   689.396       179019.273             43934.327  5.466667e+08
# 3   1963   707.731       194453.676             46823.923  7.511112e+08
# 4   1964   839.743       191982.118             51437.009  8.000000e+08
# ..   ...       ...              ...                   ...           ...
# 95  1998  1752.826      6491246.393           7889209.469  2.545967e+09
# 96  1999  2984.938      6446288.973           8013473.098  3.212119e+09
# 97  2000  3021.608      6495910.817           8183970.263  3.480355e+09
# 98  2001  3223.293      6578909.695           8386014.629  3.922099e+09
# 99  2002  3751.341      6566108.198           8787118.423  4.348070e+09
#
#      Surface  Population   PIB/Capita  CO2/Capita       CO2/PIB
# 0   652860.0   8996973.0    59.773194    0.000046  7.705245e-07
# 1   652860.0   9169410.0    59.860874    0.000054  8.952231e-07
# 2   652860.0   9351441.0    58.458015    0.000074  1.261090e-06
# 3   652860.0   9543205.0    78.706388    0.000074  9.422453e-07
# 4   652860.0   9744781.0    82.095231    0.000086  1.049679e-06
# ..       ...         ...          ...         ...           ...
# 95   28750.0   3128530.0   813.790263    0.000560  6.884715e-07
# 96   28750.0   3108778.0  1033.241693    0.000960  9.292738e-07
# 97   28750.0   3089027.0  1126.683318    0.000978  8.681895e-07
# 98   28750.0   3060173.0  1281.659393    0.001053  8.218285e-07
# 99   28750.0   3051010.0  1425.124849    0.001230  8.627600e-07
#
# [100 rows x 14 columns]

# %%
df_all.columns
# Out:
# Index(['Country', 'Country Code', 'Region', 'IncomeGroup', 'Year', 'CO2',
#        'CO2_Region_Year', 'CO2_IncomeGroup_Year', 'PIB', 'Surface',
#        'Population', 'PIB/Capita', 'CO2/Capita', 'CO2/PIB'],
#       dtype='object')

# %%
print(df_all.shape)
df_corr = df_all[['CO2', 'PIB', 'Surface', 'Population', 'PIB/Capita', 'CO2/Capita', 'CO2/PIB']].drop_duplicates()
print(df_corr.shape)
# Out:
# (12426, 14)
# (12396, 7)

# %%
df_corr.head()
# Out:
#        CO2          PIB   Surface  Population  PIB/Capita  CO2/Capita  \
# 0  414.371  537777811.1  652860.0   8996973.0   59.773194    0.000046
# 1  491.378  548888895.6  652860.0   9169410.0   59.860874    0.000054
# 2  689.396  546666677.8  652860.0   9351441.0   58.458015    0.000074
# 3  707.731  751111191.1  652860.0   9543205.0   78.706388    0.000074
# 4  839.743  800000044.4  652860.0   9744781.0   82.095231    0.000086
#
#         CO2/PIB
# 0  7.705245e-07
# 1  8.952231e-07
# 2  1.261090e-06
# 3  9.422453e-07
# 4  1.049679e-06

# %% [markdown]
# # EXTRACT COUNTRIES WITH THEIR CORRELATION CO2/PIB

# %%
countries = df_all["Country"].unique().tolist()

# %%
df_Alemania = df_all[df_all["Country"]=="Germany"][["Country", 'CO2', 'PIB']].drop_duplicates()

# %%
import math

# %%
positive_dict_of_countries_according_PIB_CO2_corr = {}
negative_dict_of_countries_according_PIB_CO2_corr = {}
indxP = 0
indxN = 0
for country in countries:
    temp = df_all[df_all["Country"]==country][["Country", 'CO2', 'PIB']].drop_duplicates()
    if temp.corr()["PIB"][0]>0 and not math.isnan(temp.corr()["PIB"][0]):
        positive_dict_of_countries_according_PIB_CO2_corr[indxP] = (country , temp.corr()["PIB"][0])
        indxP += 1
    elif not math.isnan(temp.corr()["PIB"][0]):
        negative_dict_of_countries_according_PIB_CO2_corr[indxN] = (country , temp.corr()["PIB"][0])
        indxN += 1

# %%
b = positive_dict_of_countries_according_PIB_CO2_corr.items()
print(sorted(b))
# b = b.sorted(key=lambda x:x[1][1])
# print(b)
# Out:
# [(0, ('Afghanistan', 0.9459049257219457)), (1, ('Albania', 0.027348817909068707)), (2, ('Algeria', 0.867780623439578)), (3, ('Andorra', 0.6005072026004478)), (4, ('Angola', 0.9653740803699463)), (5, ('Antigua and Barbuda', 0.7521599058322418)), (6, ('Argentina', 0.9097698000239121)), (7, ('Armenia', 0.8022491261311978)), (8, ('Aruba', 0.6243242694770029)), (9, ('Australia', 0.8355759939137193)), (10, ('Austria', 0.7296779991405957)), (11, ('Azerbaijan', 0.002687497852123662)), (12, ('Bahrain', 0.9596994736138101)), (13, ('Bangladesh', 0.9427828221398197)), (14, ('Barbados', 0.9349987914995113)), (15, ('Belarus', 0.09358084156429194)), (16, ('Belize', 0.940000104894686)), (17, ('Benin', 0.9845999520949719)), (18, ('Bermuda', 0.6366096568019372)), (19, ('Bhutan', 0.9237900385594158)), (20, ('Bolivia', 0.9390685565950039)), (21, ('Bosnia and Herzegovina', 0.9404237230589285)), (22, ('Botswana', 0.9378824465943262)), (23, ('Brazil', 0.9099752177309376)), (24, ('Brunei Darussalam', 0.47158248334010966)), (25, ('Burkina Faso', 0.9769845301384773)), (26, ('Burundi', 0.9121686592004363)), (27, ('Cabo Verde', 0.9674354197449581)), (28, ('Cambodia', 0.9837157790866391)), (29, ('Cameroon', 0.7688659011247866)), (30, ('Canada', 0.7947147230451657)), (31, ('Cayman Islands', 0.16630664851817775)), (32, ('Central African Republic', 0.808936121289936)), (33, ('Chad', 0.9108481287720096)), (34, ('Chile', 0.9438436559379598)), (35, ('China', 0.9384538499945463)), (36, ('Colombia', 0.8602557598907487)), (37, ('Comoros', 0.8781490165349048)), (38, ('Congo, Dem. Rep.', 0.08458694362309829)), (39, ('Congo, Rep.', 0.7718563026743978)), (40, ('Costa Rica', 0.8760029363763387)), (41, ("Cote d'Ivoire", 0.8045435830259072)), (42, ('Croatia', 0.16519808082373771)), (43, ('Cuba', 0.1820475165581105)), (44, ('Curacao', 0.3445699905339605)), (45, ('Cyprus', 0.8655169681528232)), (46, ('Djibouti', 0.9463683552272815)), (47, ('Dominica', 0.9589846018418257)), (48, ('Dominican Republic', 0.8769348470374082)), (49, ('Ecuador', 0.9128681117810026)), (50, ('Egypt, Arab Rep.', 0.9257584251499671)), (51, ('El Salvador', 0.9404658732934322)), (52, ('Equatorial Guinea', 0.8498295030404025)), (53, ('Estonia', 0.10990121084812347)), (54, ('Eswatini', 0.8016988861777758)), (55, ('Ethiopia', 0.9599491194310085)), (56, ('Fiji', 0.892002305546682)), (57, ('Finland', 0.5914378840968672)), (58, ('French Polynesia', 0.7733788406614134)), (59, ('Gabon', 0.3875209812836248)), (60, ('Gambia, The', 0.9294130736521871)), (61, ('Georgia', 0.4463176320197693)), (62, ('Ghana', 0.9341822705337895)), (63, ('Greece', 0.8176117903614218)), (64, ('Greenland', 0.362514441206944)), (65, ('Grenada', 0.9658696419609275)), (66, ('Guatemala', 0.9336495164206504)), (67, ('Guinea', 0.8783738575423002)), (68, ('Guinea-Bissau', 0.8215235619940383)), (69, ('Guyana', 0.565709965671369)), (70, ('Haiti', 0.9466005097178976)), (71, ('Honduras', 0.9504721371188489)), (72, ('Hong Kong SAR, China', 0.9148412876402231)), (73, ('Iceland', 0.7499297825115201)), (74, ('India', 0.9700143398631362)), (75, ('Indonesia', 0.9044307357357998)), (76, ('Iran, Islamic Rep.', 0.8912596153860222)), (77, ('Iraq', 0.8740109963788996)), (78, ('Ireland', 0.7770528969011542)), (79, ('Israel', 0.9043509574523069)), (80, ('Italy', 0.6642413594392187)), (81, ('Jamaica', 0.6458033269940762)), (82, ('Japan', 0.8467734635841402)), (83, ('Jordan', 0.880649087237962)), (84, ('Kazakhstan', 0.7828078296101914)), (85, ('Kenya', 0.929308963436523)), (86, ('Kiribati', 0.8896512801437322)), (87, ('Korea, Rep.', 0.9504716156734277)), (88, ('Kuwait', 0.899893870921804)), (89, ('Kyrgyz Republic', 0.76222397705031)), (90, ('Lao PDR', 0.8461603562925344)), (91, ('Lebanon', 0.9552382794329334)), (92, ('Lesotho', 0.9406385665710846)), (93, ('Liberia', 0.9046890966050801)), (94, ('Libya', 0.6048746803051517)), (95, ('Macao SAR, China', 0.5141091779009509)), (96, ('Madagascar', 0.8798986191467423)), (97, ('Malawi', 0.8747115607538235)), (98, ('Mala ...

# %%
print(positive_dict_of_countries_according_PIB_CO2_corr)
# Out:
# {0: ('Afghanistan', 0.9459049257219457), 1: ('Albania', 0.027348817909068707), 2: ('Algeria', 0.867780623439578), 3: ('Andorra', 0.6005072026004478), 4: ('Angola', 0.9653740803699463), 5: ('Antigua and Barbuda', 0.7521599058322418), 6: ('Argentina', 0.9097698000239121), 7: ('Armenia', 0.8022491261311978), 8: ('Aruba', 0.6243242694770029), 9: ('Australia', 0.8355759939137193), 10: ('Austria', 0.7296779991405957), 11: ('Azerbaijan', 0.002687497852123662), 12: ('Bahrain', 0.9596994736138101), 13: ('Bangladesh', 0.9427828221398197), 14: ('Barbados', 0.9349987914995113), 15: ('Belarus', 0.09358084156429194), 16: ('Belize', 0.940000104894686), 17: ('Benin', 0.9845999520949719), 18: ('Bermuda', 0.6366096568019372), 19: ('Bhutan', 0.9237900385594158), 20: ('Bolivia', 0.9390685565950039), 21: ('Bosnia and Herzegovina', 0.9404237230589285), 22: ('Botswana', 0.9378824465943262), 23: ('Brazil', 0.9099752177309376), 24: ('Brunei Darussalam', 0.47158248334010966), 25: ('Burkina Faso', 0.9769845301384773), 26: ('Burundi', 0.9121686592004363), 27: ('Cabo Verde', 0.9674354197449581), 28: ('Cambodia', 0.9837157790866391), 29: ('Cameroon', 0.7688659011247866), 30: ('Canada', 0.7947147230451657), 31: ('Cayman Islands', 0.16630664851817775), 32: ('Central African Republic', 0.808936121289936), 33: ('Chad', 0.9108481287720096), 34: ('Chile', 0.9438436559379598), 35: ('China', 0.9384538499945463), 36: ('Colombia', 0.8602557598907487), 37: ('Comoros', 0.8781490165349048), 38: ('Congo, Dem. Rep.', 0.08458694362309829), 39: ('Congo, Rep.', 0.7718563026743978), 40: ('Costa Rica', 0.8760029363763387), 41: ("Cote d'Ivoire", 0.8045435830259072), 42: ('Croatia', 0.16519808082373771), 43: ('Cuba', 0.1820475165581105), 44: ('Curacao', 0.3445699905339605), 45: ('Cyprus', 0.8655169681528232), 46: ('Djibouti', 0.9463683552272815), 47: ('Dominica', 0.9589846018418257), 48: ('Dominican Republic', 0.8769348470374082), 49: ('Ecuador', 0.9128681117810026), 50: ('Egypt, Arab Rep.', 0.9257584251499671), 51: ('El Salvador', 0.9404658732934322), 52: ('Equatorial Guinea', 0.8498295030404025), 53: ('Estonia', 0.10990121084812347), 54: ('Eswatini', 0.8016988861777758), 55: ('Ethiopia', 0.9599491194310085), 56: ('Fiji', 0.892002305546682), 57: ('Finland', 0.5914378840968672), 58: ('French Polynesia', 0.7733788406614134), 59: ('Gabon', 0.3875209812836248), 60: ('Gambia, The', 0.9294130736521871), 61: ('Georgia', 0.4463176320197693), 62: ('Ghana', 0.9341822705337895), 63: ('Greece', 0.8176117903614218), 64: ('Greenland', 0.362514441206944), 65: ('Grenada', 0.9658696419609275), 66: ('Guatemala', 0.9336495164206504), 67: ('Guinea', 0.8783738575423002), 68: ('Guinea-Bissau', 0.8215235619940383), 69: ('Guyana', 0.565709965671369), 70: ('Haiti', 0.9466005097178976), 71: ('Honduras', 0.9504721371188489), 72: ('Hong Kong SAR, China', 0.9148412876402231), 73: ('Iceland', 0.7499297825115201), 74: ('India', 0.9700143398631362), 75: ('Indonesia', 0.9044307357357998), 76: ('Iran, Islamic Rep.', 0.8912596153860222), 77: ('Iraq', 0.8740109963788996), 78: ('Ireland', 0.7770528969011542), 79: ('Israel', 0.9043509574523069), 80: ('Italy', 0.6642413594392187), 81: ('Jamaica', 0.6458033269940762), 82: ('Japan', 0.8467734635841402), 83: ('Jordan', 0.880649087237962), 84: ('Kazakhstan', 0.7828078296101914), 85: ('Kenya', 0.929308963436523), 86: ('Kiribati', 0.8896512801437322), 87: ('Korea, Rep.', 0.9504716156734277), 88: ('Kuwait', 0.899893870921804), 89: ('Kyrgyz Republic', 0.76222397705031), 90: ('Lao PDR', 0.8461603562925344), 91: ('Lebanon', 0.9552382794329334), 92: ('Lesotho', 0.9406385665710846), 93: ('Liberia', 0.9046890966050801), 94: ('Libya', 0.6048746803051517), 95: ('Macao SAR, China', 0.5141091779009509), 96: ('Madagascar', 0.8798986191467423), 97: ('Malawi', 0.8747115607538235), 98: ('Malaysia', 0.9575268481238033), 99: ('Maldives', 0.980446160622968), 100: ('Mali', 0.973716269085812), 101: ('Malta', 0.6461520700673359), 102: ('Marshall Islands', 0.9610730494246561), 103: ('Mauritan ...

# %%
print(negative_dict_of_countries_according_PIB_CO2_corr)
# Out:
# {0: ('Bahamas, The', -0.296035262887938), 1: ('Belgium', -0.400715596872361), 2: ('Bulgaria', -0.4192363675704776), 3: ('Czech Republic', -0.7810220693917247), 4: ('Denmark', -0.645305474254396), 5: ('Eritrea', -0.5866735971161017), 6: ('Faroe Islands', -0.5700057273305718), 7: ('France', -0.36675800012241094), 8: ('Germany', -0.8811905911409773), 9: ('Hungary', -0.7729138098632524), 10: ('Kosovo', -0.12098442790303737), 11: ('Latvia', -0.23295251106015472), 12: ('Liechtenstein', -0.7070357058665588), 13: ('Lithuania', -0.3257263204202995), 14: ('Luxembourg', -0.28467268117959765), 15: ('Moldova', -0.22093259350170613), 16: ('North Macedonia', -0.8555379691517151), 17: ('Poland', -0.6749288695135102), 18: ('Romania', -0.586926254815409), 19: ('Russian Federation', -0.16202422559854693), 20: ('Serbia', -0.36233009538711447), 21: ('Slovak Republic', -0.8417825333654014), 22: ('South Sudan', -0.32430477880794795), 23: ('Sweden', -0.6773866993063011), 24: ('Ukraine', -0.3823340029465775), 25: ('United Kingdom', -0.8408003398059744), 26: ('Uzbekistan', -0.6262482930539478)}

# %%
sorted(negative_dict_of_countries_according_PIB_CO2_corr.items(), key=lambda t: t[1][1])
# Out:
# [(8, ('Germany', -0.8811905911409773)),
#  (16, ('North Macedonia', -0.8555379691517151)),
#  (21, ('Slovak Republic', -0.8417825333654014)),
#  (25, ('United Kingdom', -0.8408003398059744)),
#  (3, ('Czech Republic', -0.7810220693917247)),
#  (9, ('Hungary', -0.7729138098632524)),
#  (12, ('Liechtenstein', -0.7070357058665588)),
#  (23, ('Sweden', -0.6773866993063011)),
#  (17, ('Poland', -0.6749288695135102)),
#  (4, ('Denmark', -0.645305474254396)),
#  (26, ('Uzbekistan', -0.6262482930539478)),
#  (18, ('Romania', -0.586926254815409)),
#  (5, ('Eritrea', -0.5866735971161017)),
#  (6, ('Faroe Islands', -0.5700057273305718)),
#  (2, ('Bulgaria', -0.4192363675704776)),
#  (1, ('Belgium', -0.400715596872361)),
#  (24, ('Ukraine', -0.3823340029465775)),
#  (7, ('France', -0.36675800012241094)),
#  (20, ('Serbia', -0.36233009538711447)),
#  (13, ('Lithuania', -0.3257263204202995)),
#  (22, ('South Sudan', -0.32430477880794795)),
#  (0, ('Bahamas, The', -0.296035262887938)),
#  (14, ('Luxembourg', -0.28467268117959765)),
#  (11, ('Latvia', -0.23295251106015472)),
#  (15, ('Moldova', -0.22093259350170613)),
#  (19, ('Russian Federation', -0.16202422559854693)),
#  (10, ('Kosovo', -0.12098442790303737))]

# %%
for i in positive_dict_of_countries_according_PIB_CO2_corr:
    print(positive_dict_of_countries_according_PIB_CO2_corr.get(i))
# Out:
# ('Afghanistan', 0.9459049257219457)
# ('Albania', 0.027348817909068707)
# ('Algeria', 0.867780623439578)
# ('Andorra', 0.6005072026004478)
# ('Angola', 0.9653740803699463)
# ('Antigua and Barbuda', 0.7521599058322418)
# ('Argentina', 0.9097698000239121)
# ('Armenia', 0.8022491261311978)
# ('Aruba', 0.6243242694770029)
# ('Australia', 0.8355759939137193)
# ('Austria', 0.7296779991405957)
# ('Azerbaijan', 0.002687497852123662)
# ('Bahrain', 0.9596994736138101)
# ('Bangladesh', 0.9427828221398197)
# ('Barbados', 0.9349987914995113)
# ('Belarus', 0.09358084156429194)
# ('Belize', 0.940000104894686)
# ('Benin', 0.9845999520949719)
# ('Bermuda', 0.6366096568019372)
# ('Bhutan', 0.9237900385594158)
# ('Bolivia', 0.9390685565950039)
# ('Bosnia and Herzegovina', 0.9404237230589285)
# ('Botswana', 0.9378824465943262)
# ('Brazil', 0.9099752177309376)
# ('Brunei Darussalam', 0.47158248334010966)
# ('Burkina Faso', 0.9769845301384773)
# ('Burundi', 0.9121686592004363)
# ('Cabo Verde', 0.9674354197449581)
# ('Cambodia', 0.9837157790866391)
# ('Cameroon', 0.7688659011247866)
# ('Canada', 0.7947147230451657)
# ('Cayman Islands', 0.16630664851817775)
# ('Central African Republic', 0.808936121289936)
# ('Chad', 0.9108481287720096)
# ('Chile', 0.9438436559379598)
# ('China', 0.9384538499945463)
# ('Colombia', 0.8602557598907487)
# ('Comoros', 0.8781490165349048)
# ('Congo, Dem. Rep.', 0.08458694362309829)
# ('Congo, Rep.', 0.7718563026743978)
# ('Costa Rica', 0.8760029363763387)
# ("Cote d'Ivoire", 0.8045435830259072)
# ('Croatia', 0.16519808082373771)
# ('Cuba', 0.1820475165581105)
# ('Curacao', 0.3445699905339605)
# ('Cyprus', 0.8655169681528232)
# ('Djibouti', 0.9463683552272815)
# ('Dominica', 0.9589846018418257)
# ('Dominican Republic', 0.8769348470374082)
# ('Ecuador', 0.9128681117810026)
# ('Egypt, Arab Rep.', 0.9257584251499671)
# ('El Salvador', 0.9404658732934322)
# ('Equatorial Guinea', 0.8498295030404025)
# ('Estonia', 0.10990121084812347)
# ('Eswatini', 0.8016988861777758)
# ('Ethiopia', 0.9599491194310085)
# ('Fiji', 0.892002305546682)
# ('Finland', 0.5914378840968672)
# ('French Polynesia', 0.7733788406614134)
# ('Gabon', 0.3875209812836248)
# ('Gambia, The', 0.9294130736521871)
# ('Georgia', 0.4463176320197693)
# ('Ghana', 0.9341822705337895)
# ('Greece', 0.8176117903614218)
# ('Greenland', 0.362514441206944)
# ('Grenada', 0.9658696419609275)
# ('Guatemala', 0.9336495164206504)
# ('Guinea', 0.8783738575423002)
# ('Guinea-Bissau', 0.8215235619940383)
# ('Guyana', 0.565709965671369)
# ('Haiti', 0.9466005097178976)
# ('Honduras', 0.9504721371188489)
# ('Hong Kong SAR, China', 0.9148412876402231)
# ('Iceland', 0.7499297825115201)
# ('India', 0.9700143398631362)
# ('Indonesia', 0.9044307357357998)
# ('Iran, Islamic Rep.', 0.8912596153860222)
# ('Iraq', 0.8740109963788996)
# ('Ireland', 0.7770528969011542)
# ('Israel', 0.9043509574523069)
# ('Italy', 0.6642413594392187)
# ('Jamaica', 0.6458033269940762)
# ('Japan', 0.8467734635841402)
# ('Jordan', 0.880649087237962)
# ('Kazakhstan', 0.7828078296101914)
# ('Kenya', 0.929308963436523)
# ('Kiribati', 0.8896512801437322)
# ('Korea, Rep.', 0.9504716156734277)
# ('Kuwait', 0.899893870921804)
# ('Kyrgyz Republic', 0.76222397705031)
# ('Lao PDR', 0.8461603562925344)
# ('Lebanon', 0.9552382794329334)
# ('Lesotho', 0.9406385665710846)
# ('Liberia', 0.9046890966050801)
# ('Libya', 0.6048746803051517)
# ('Macao SAR, China', 0.5141091779009509)
# ('Madagascar', 0.8798986191467423)
# ('Malawi', 0.8747115607538235)
# ('Malaysia', 0.9575268481238033)
# ('Maldives', 0.980446160622968)
# ('Mali', 0.973716269085812)
# ('Malta', 0.6461520700673359)
# ('Marshall Islands', 0.9610730494246561)
# ('Mauritania', 0.7782872274705177)
# ('Mauritius', 0.9598054033767475)
# ('Mexico', 0.9035090538816284)
# ('Micronesia, Fed. Sts.', 0.45804219984500344)
# ('Mongolia', 0.9227171188120753)
# ('Montenegro', 0.30850119091310957)
# ('Morocco', 0.9827809987665086)
# ('Mozambique', 0.7721751849181518)
# ('Myanmar', 0.7152620246177329)
# ('Namibia', 0.8632753134455378)
# ('Nauru', 0.3734420743578404)
# ('Nepal', 0.9611110420977006)
# ('Netherlands', 0.6616143907503972)
# ('New Caledonia', 0.09391464744322417)
# ('New Zealand', 0.83921400053055)
# ('Nicaragua', 0.9276985125035797)
# ('Niger', 0.8786647064941142)
# ('Nigeria', 0.8302796700723353)
# ('Norway', 0.7318643726305416)
# ('Oman', 0.979128211084275)
# ('Pacific island small states', 0.9101640225155989)
# ('Pakistan', 0.9578065143117926)
# ('Palau', 0.32946576754523277)
# ('Panama', 0.9411628474711017)
# ('Papua New Guinea', 0.8777000652029495)
# ('Paraguay', 0.8705579832993974)
# ('Peru', 0.9401270821423721)
# ('Philippines', 0.9201854310646539)
# ('Portugal', 0.8291546655448712)
# ('Qatar', 0.9351061035354765)
# ('Rwanda', 0.798781138742571)
# ('Samoa', 0.9702650154791199)
# ('Sao Tome and Principe', 0.9541693765547984)
# ('Saudi Arabia', 0.9363179718482763)
# ('Senegal', 0.9338282206099053)
# ('Seychelles', 0.8488938771766776)
# ('Sierra Leone', 0.7630443457302717)
# ('Singapore', 0.607824079697292)
# ('Sint Maarten (Dutch part)', 0.9244502980573368)
# ('Slovenia', 0.2046584584529929)
# ('Solomon Islands', 0.710305307101704)
# ('Somalia', 0.9040133586845527)
# ('South Africa', 0.9029935708736794)
# ('Spain', 0.7896344239862688)
# ('Sri Lanka', 0.9375583021656714)
# ('St. Kitts and Nevis', 0.9697686223501495)
# ('St. Lucia', 0.9357442250951185)
# ('St. Vincent and the Grenadines', 0.9714992175092876)
# ('Sudan', 0.9491726582318214)
# ('Suriname', 0.3618255034172047)
# ('Switzerland', 0.23696282444553377)
# ('Syrian Arab Republic', 0.8694655992225755)
# ('Tajikistan', 0.30706790496273895)
# ('Tanzania', 0.9787044695432129)
# ('Thailand', 0.9485793507868995)
# ('Timor-Leste', 0.960470095607204)
# ('Togo', 0.962469967908274)
# ('Tonga', 0.8627077405664478)
# ('Trinidad and Tobago', 0.9653013033116339)
# ('Tunisia', 0.9660475325489541)
# ('Turkey', 0.9385952588190213)
# ('Turkmenistan', 0.9390372730189008)
# ('Turks and Caicos Islands', 0.9310697115397426)
# ('Tuvalu', 0.6302945606970752)
# ('Uganda', 0.958770289045106)
# ('United Arab Emirates', 0.9786268719110385)
# ('United States', 0.747838299145783)
# ('Uruguay', 0.6671866948884134)
# ('Vanuatu', 0.819982605697746)
# ('Venezuela, RB', 0.7787389016879812)
# ('Vietnam', 0.9589883160888877)
# ('West Bank and Gaza', 0.81033619902648)
# ('Yemen, Rep.', 0.6829750969544006)
# ('Zambia', 0.12303258956518788)
# ('Zimbabwe', 0.2965865969162254)

# %%
for i in negative_dict_of_countries_according_PIB_CO2_corr:
    print(negative_dict_of_countries_according_PIB_CO2_corr.get(i))
# Out:
# ('Bahamas, The', -0.296035262887938)
# ('Belgium', -0.400715596872361)
# ('Bulgaria', -0.4192363675704776)
# ('Czech Republic', -0.7810220693917247)
# ('Denmark', -0.645305474254396)
# ('Eritrea', -0.5866735971161017)
# ('Faroe Islands', -0.5700057273305718)
# ('France', -0.36675800012241094)
# ('Germany', -0.8811905911409773)
# ('Hungary', -0.7729138098632524)
# ('Kosovo', -0.12098442790303737)
# ('Latvia', -0.23295251106015472)
# ('Liechtenstein', -0.7070357058665588)
# ('Lithuania', -0.3257263204202995)
# ('Luxembourg', -0.28467268117959765)
# ('Moldova', -0.22093259350170613)
# ('North Macedonia', -0.8555379691517151)
# ('Poland', -0.6749288695135102)
# ('Romania', -0.586926254815409)
# ('Russian Federation', -0.16202422559854693)
# ('Serbia', -0.36233009538711447)
# ('Slovak Republic', -0.8417825333654014)
# ('South Sudan', -0.32430477880794795)
# ('Sweden', -0.6773866993063011)
# ('Ukraine', -0.3823340029465775)
# ('United Kingdom', -0.8408003398059744)
# ('Uzbekistan', -0.6262482930539478)

# %%
g=sns.heatmap(df_Alemania.corr(), annot=True, cmap="Blues")
g.set(title='Le PIB, la superficie et la population sont les plus corrélés au CO2')
g.title.set_size(20)

# %%
df_Alemania.corr()["PIB"][0]
# Out:
# -0.8811905911409773

# %% [markdown]
# # Analyse bivariée

# %% [markdown]
# ### Matrice de correlation

# %%
df_corr.head()
# Out:
#        CO2          PIB   Surface  Population  PIB/Capita  CO2/Capita  \
# 0  414.371  537777811.1  652860.0   8996973.0   59.773194    0.000046
# 1  491.378  548888895.6  652860.0   9169410.0   59.860874    0.000054
# 2  689.396  546666677.8  652860.0   9351441.0   58.458015    0.000074
# 3  707.731  751111191.1  652860.0   9543205.0   78.706388    0.000074
# 4  839.743  800000044.4  652860.0   9744781.0   82.095231    0.000086
#
#         CO2/PIB
# 0  7.705245e-07
# 1  8.952231e-07
# 2  1.261090e-06
# 3  9.422453e-07
# 4  1.049679e-06

# %%
plt.figure(figsize=(14,10))
g=sns.heatmap(df_corr.corr(), annot=True, cmap="Blues")
g.set(title='Le PIB, la superficie et la population sont les plus corrélés au CO2')
g.title.set_size(20)

# %% [markdown]
# ### Tableau de contingence 2016

# %%
df_cont16 = df_all[df_all['Year']=="2016"]

t_contingence2016 = pd.crosstab(df_cont16['Region'],
                            df_cont16['IncomeGroup'], 
                               margins = False)
print(t_contingence2016)
# Out:
# IncomeGroup                 High income  Low income  Lower middle income  \
# Region
# East Asia & Pacific                  14           1                   12
# Europe & Central Asia                38           1                    4
# Latin America & Caribbean            17           1                    4
# Middle East & North Africa            8           2                    6
# North America                         3           0                    0
# South Asia                            0           1                    6
# Sub-Saharan Africa                    2          23                   18
#
# IncomeGroup                 Upper middle income
# Region
# East Asia & Pacific                          10
# Europe & Central Asia                        15
# Latin America & Caribbean                    20
# Middle East & North Africa                    5
# North America                                 0
# South Asia                                    1
# Sub-Saharan Africa                            5

# %% [markdown]
# ### Tableau de contingence 1960

# %%
df_cont60 = df_all[df_all['Year']=="1960"]

t_contingence1960 = pd.crosstab(df_cont60['Region'],
                            df_cont60['IncomeGroup'], 
                               margins = False)
print(t_contingence1960)
# Out:
# IncomeGroup                 High income  Low income  Lower middle income  \
# Region
# East Asia & Pacific                  14           1                   12
# Europe & Central Asia                38           1                    4
# Latin America & Caribbean            17           1                    4
# Middle East & North Africa            8           2                    6
# North America                         3           0                    0
# South Asia                            0           1                    6
# Sub-Saharan Africa                    2          23                   18
#
# IncomeGroup                 Upper middle income
# Region
# East Asia & Pacific                          10
# Europe & Central Asia                        15
# Latin America & Caribbean                    20
# Middle East & North Africa                    5
# North America                                 0
# South Asia                                    1
# Sub-Saharan Africa                            5

# %% [markdown]
# ## Nuage des points

# %%
df_all2016 = df_all[df_all["Year"]=="2016"]

# %% [markdown]
# ## Bivarie entre PIB et CO2

# %% [markdown]
# ### Hypothèse : les points orange representent la Chine et les rouges les Etats Unis

# %%
plt.figure(figsize=(15,10))
g=sns.scatterplot(data=df_all, x="PIB", y="CO2", hue="IncomeGroup")
g.set(title='Bivarie entre PIB et CO2')
g.title.set_size(20)

# %% [markdown]
# ### le même pour 2016

# %%
plt.figure(figsize=(15,10))
g=sns.scatterplot(data=df_all2016, x="PIB", y="CO2", hue="IncomeGroup")
g.set(title='Focus sur année 2016')
g.title.set_size(20)

# %% [markdown]
# #### On voit qu'il y a deux pays qui sont des valeurs Extremes (outliers)

# %% [markdown]
# ## Bivarie entre Population et CO2

# %%
plt.figure(figsize=(15,10))
g=sns.scatterplot(data=df_all, x="Population", y="CO2", hue="IncomeGroup")
g.set(title='Lien entre population et émission de CO2')
g.title.set_size(20)

# %% [markdown]
# ## Top 10 des pays les plus polluants en 2016

# %%
df_all2016['pctg_CO2_2016'] = (df_all2016['CO2'] / df_all2016['CO2'].sum())*100
# Out:
# <ipython-input-381-53cb7d0af7f6>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_all2016['pctg_CO2_2016'] = (df_all2016['CO2'] / df_all2016['CO2'].sum())*100

# %%
df_all2016 = df_all2016.sort_values(by="pctg_CO2_2016", ascending = False)

# %%
df_all2016.head()
# Out:
#                   Country Country Code                 Region  \
# 2393                China          CHN    East Asia & Pacific
# 11855       United States          USA          North America
# 5129                India          IND             South Asia
# 9290   Russian Federation          RUS  Europe & Central Asia
# 5642                Japan          JPN    East Asia & Pacific
#
#                IncomeGroup  Year          CO2  CO2_Region_Year  \
# 2393   Upper middle income  2016  9893037.952     1.368487e+07
# 11855          High income  2016  5006302.077     5.551809e+06
# 5129   Lower middle income  2016  2407671.526     2.736913e+06
# 9290   Upper middle income  2016  1732026.776     5.639908e+06
# 5642           High income  2016  1135886.253     1.368487e+07
#
#        CO2_IncomeGroup_Year           PIB     Surface    Population  \
# 2393           1.671832e+07  1.123330e+13   9600012.9  1.378665e+09
# 11855          1.177276e+07  1.871500e+13   9831510.0  3.229413e+08
# 5129           4.229048e+06  2.294800e+12   3287259.0  1.324510e+09
# 9290           1.671832e+07  1.276790e+12  17098250.0  1.443424e+08
# 5642           1.177276e+07  4.922540e+12    377974.0  1.269945e+08
#
#          PIB/Capita  CO2/Capita       CO2/PIB  pctg_CO2_2016
# 2393    8147.954724    0.007176  8.806885e-07      30.081164
# 11855  57951.706278    0.015502  2.675021e-07      15.222361
# 5129    1732.565788    0.001818  1.049186e-06       7.320862
# 9290    8845.564620    0.011999  1.356548e-06       5.266469
# 5642   38761.832785    0.008944  2.307521e-07       3.453821

# %% [markdown]
# ### Conserver que les dix les plus polluants en 2016

# %%
df_top10 = df_all2016.head(10)

# %%
df_top10['Country'].unique().tolist()
# Out:
# ['China',
#  'United States',
#  'India',
#  'Russian Federation',
#  'Japan',
#  'Germany',
#  'Iran, Islamic Rep.',
#  'Korea, Rep.',
#  'Saudi Arabia',
#  'Indonesia']

# %%
df_all_top = df_all[df_all['Country'].isin(df_top10['Country'].unique().tolist())]

# %%
df_all_top.head(10)
# Out:
#      Country Country Code               Region          IncomeGroup  Year  \
# 2337   China          CHN  East Asia & Pacific  Upper middle income  1960
# 2338   China          CHN  East Asia & Pacific  Upper middle income  1961
# 2339   China          CHN  East Asia & Pacific  Upper middle income  1962
# 2340   China          CHN  East Asia & Pacific  Upper middle income  1963
# 2341   China          CHN  East Asia & Pacific  Upper middle income  1964
# 2342   China          CHN  East Asia & Pacific  Upper middle income  1965
# 2343   China          CHN  East Asia & Pacific  Upper middle income  1966
# 2344   China          CHN  East Asia & Pacific  Upper middle income  1967
# 2345   China          CHN  East Asia & Pacific  Upper middle income  1968
# 2346   China          CHN  East Asia & Pacific  Upper middle income  1969
#
#              CO2  CO2_Region_Year  CO2_IncomeGroup_Year           PIB  \
# 2337  780726.302      1202974.018           2708981.582  5.971647e+10
# 2338  552066.850      1039169.128           2543500.873  5.005687e+10
# 2339  440359.029       950919.106           2530285.005  4.720936e+10
# 2340  436695.696       995212.799           2659411.076  5.070680e+10
# 2341  436923.050      1048960.018           2818760.561  5.970834e+10
# 2342  475972.933      1142956.229           3008249.119  7.043627e+10
# 2343  522789.522      1234513.885           3209105.377  7.672029e+10
# 2344  433234.048      1243828.065           3265848.535  7.288163e+10
# 2345  468928.626      1381505.580           3432121.316  7.084654e+10
# 2346  577237.138      1609468.302           3689918.750  7.970591e+10
#
#         Surface   Population  PIB/Capita  CO2/Capita   CO2/PIB
# 2337  9600012.9  667070000.0   89.520542    0.001170  0.000013
# 2338  9600012.9  660330000.0   75.805838    0.000836  0.000011
# 2339  9600012.9  665770000.0   70.909412    0.000661  0.000009
# 2340  9600012.9  682335000.0   74.313643    0.000640  0.000009
# 2341  9600012.9  698355000.0   85.498555    0.000626  0.000007
# 2342  9600012.9  715185000.0   98.486778    0.000666  0.000007
# 2343  9600012.9  735400000.0  104.324566    0.000711  0.000007
# 2344  9600012.9  754550000.0   96.589532    0.000574  0.000006
# 2345  9600012.9  774510000.0   91.472718    0.000605  0.000007
# 2346  9600012.9  796025000.0  100.129903    0.000725  0.000007

# %%
df_all_top['CO2/surface'] = df_all_top['CO2']/df_all_top['Surface']
# Out:
# <ipython-input-388-cc73f737b82e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_all_top['CO2/surface'] = df_all_top['CO2']/df_all_top['Surface']

# %%
df_all_top['CO2/population'] = df_all_top['CO2']/df_all_top['Population']
# Out:
# <ipython-input-389-1b6fe1f11c07>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_all_top['CO2/population'] = df_all_top['CO2']/df_all_top['Population']

# %%
df_all_top = df_all_top.drop_duplicates()

# %%
df_all_top['CO2/PIB'] = df_all_top['CO2']/df_all_top['PIB']

# %%
df_all_top.head()
# Out:
#      Country Country Code               Region          IncomeGroup  Year  \
# 2337   China          CHN  East Asia & Pacific  Upper middle income  1960
# 2338   China          CHN  East Asia & Pacific  Upper middle income  1961
# 2339   China          CHN  East Asia & Pacific  Upper middle income  1962
# 2340   China          CHN  East Asia & Pacific  Upper middle income  1963
# 2341   China          CHN  East Asia & Pacific  Upper middle income  1964
#
#              CO2  CO2_Region_Year  CO2_IncomeGroup_Year           PIB  \
# 2337  780726.302      1202974.018           2708981.582  5.971647e+10
# 2338  552066.850      1039169.128           2543500.873  5.005687e+10
# 2339  440359.029       950919.106           2530285.005  4.720936e+10
# 2340  436695.696       995212.799           2659411.076  5.070680e+10
# 2341  436923.050      1048960.018           2818760.561  5.970834e+10
#
#         Surface   Population  PIB/Capita  CO2/Capita   CO2/PIB  CO2/surface  \
# 2337  9600012.9  667070000.0   89.520542    0.001170  0.000013     0.081326
# 2338  9600012.9  660330000.0   75.805838    0.000836  0.000011     0.057507
# 2339  9600012.9  665770000.0   70.909412    0.000661  0.000009     0.045871
# 2340  9600012.9  682335000.0   74.313643    0.000640  0.000009     0.045489
# 2341  9600012.9  698355000.0   85.498555    0.000626  0.000007     0.045513
#
#       CO2/population
# 2337        0.001170
# 2338        0.000836
# 2339        0.000661
# 2340        0.000640
# 2341        0.000626

# %% [markdown]
# ## Evolution des emissions de CO2/surface du top 10 de 2016

# %%
plt.figure(figsize=(19,10))

g = sns.lineplot(data=df_all_top, x="Year", y="CO2/PIB", hue="Country")

g.set(title='Emissions de CO2/PIB des 10 les plus polluants en 2016')
# g.title.set_size(30)
# g.xaxis.label.set_size(16)
# g.yaxis.label.set_size(16)
# # g.legend(fontsize=100)
# g.legend(fontsize="larger")
# g.legend(loc='center left',bbox_to_anchor=(1, 0.5))
# g.grid()
# g.tick_params(axis='x',which='minor',direction='out',bottom=True,length=5)
# g.set_xticklabels(labels,  rotation=90, 
#     horizontalalignment='center',
#     fontweight='light',
#     fontsize='x-large')
# g.set_yticklabels(labelsy.astype(int),
#     fontweight='light',
#     fontsize='x-large')
# Out:
# [Text(0.5, 1.0, 'Emissions de CO2/PIB des 10 les plus polluants en 2016')]

# %%
plt.figure(figsize=(19,10))

g = sns.lineplot(data=df_all_top, x="Year", y="CO2/surface", hue="Country")

g.set(title='Emissions de CO2/surface des 10 les plus polluants en 2016')
g.title.set_size(30)
g.xaxis.label.set_size(16)
g.yaxis.label.set_size(16)
# g.legend(fontsize=100)
g.legend(fontsize="larger")
g.legend(loc='center left',bbox_to_anchor=(1, 0.5))
g.grid()
g.tick_params(axis='x',which='minor',direction='out',bottom=True,length=5)
g.set_xticklabels(labels,  rotation=90, 
    horizontalalignment='center',
    fontweight='light',
    fontsize='x-large')
g.set_yticklabels(labelsy.astype(int),
    fontweight='light',
    fontsize='x-large')
# Out:
# <ipython-input-394-41318a4565c5>:14: UserWarning: FixedFormatter should only be used together with FixedLocator
#   g.set_xticklabels(labels,  rotation=90,
# <ipython-input-394-41318a4565c5>:18: UserWarning: FixedFormatter should only be used together with FixedLocator
#   g.set_yticklabels(labelsy.astype(int),
# [Text(0, -1.0, '151645'),
#  Text(0, 0.0, '162624'),
#  Text(0, 1.0, '179019'),
#  Text(0, 2.0, '194453'),
#  Text(0, 3.0, '191982'),
#  Text(0, 4.0, '209767'),
#  Text(0, 5.0, '216364'),
#  Text(0, 6.0, '219829'),
#  Text(0, 7.0, '241530')]

# %% [markdown]
# ## Evolution des emissions de CO2/population du top 10 de 2016

# %%
plt.figure(figsize=(19,10))
g = sns.lineplot(data=df_all_top, x="Year", y="CO2/population", hue="Country")

g.set(title='Emissions de CO2 per capita des 10 pays les plus polluants en 2016')
g.title.set_size(30)
g.xaxis.label.set_size(16)
g.yaxis.label.set_size(16)
g.legend(fontsize=50)
g.legend(fontsize="larger")
g.legend(loc='center left',bbox_to_anchor=(1, 0.5))
g.grid()
g.tick_params(axis='x',which='minor',direction='out',bottom=True,length=5)
g.set_xticklabels(labels,  rotation=90, 
    horizontalalignment='center',
    fontweight='light',
    fontsize='x-large')
g.set_yticklabels(labelsy.astype(int),
    fontweight='light',
    fontsize='x-large')
# Out:
# <ipython-input-395-cfd4cb65f861>:13: UserWarning: FixedFormatter should only be used together with FixedLocator
#   g.set_xticklabels(labels,  rotation=90,
# <ipython-input-395-cfd4cb65f861>:17: UserWarning: FixedFormatter should only be used together with FixedLocator
#   g.set_yticklabels(labelsy.astype(int),
# [Text(0, -0.005, '151645'),
#  Text(0, 0.0, '162624'),
#  Text(0, 0.005, '179019'),
#  Text(0, 0.009999999999999998, '194453'),
#  Text(0, 0.015, '191982'),
#  Text(0, 0.02, '209767'),
#  Text(0, 0.024999999999999998, '216364'),
#  Text(0, 0.030000000000000002, '219829')]

# %%
plt.figure(figsize=(19,10))
g = sns.lineplot(data=df_all_top, x="Year", y="CO2", hue="Country")

g.set(title='Emissions de CO2 des 10 pays les plus polluants en 2016')
g.title.set_size(30)
g.xaxis.label.set_size(16)
g.yaxis.label.set_size(16)
g.legend(fontsize=50)
g.legend(fontsize="larger")
g.legend(loc='center left',bbox_to_anchor=(1, 0.5))
g.grid()
g.tick_params(axis='x',which='minor',direction='out',bottom=True,length=5)
g.set_xticklabels(labels,  rotation=90, 
    horizontalalignment='center',
    fontweight='light',
    fontsize='x-large')
g.set_yticklabels(labelsy.astype(int),
    fontweight='light',
    fontsize='x-large')
# Out:
# <ipython-input-396-93f73cd28183>:13: UserWarning: FixedFormatter should only be used together with FixedLocator
#   g.set_xticklabels(labels,  rotation=90,
# <ipython-input-396-93f73cd28183>:17: UserWarning: FixedFormatter should only be used together with FixedLocator
#   g.set_yticklabels(labelsy.astype(int),
# [Text(0, -2000000.0, '151645'),
#  Text(0, 0.0, '162624'),
#  Text(0, 2000000.0, '179019'),
#  Text(0, 4000000.0, '194453'),
#  Text(0, 6000000.0, '191982'),
#  Text(0, 8000000.0, '209767'),
#  Text(0, 10000000.0, '216364'),
#  Text(0, 12000000.0, '219829')]
